# %%
import cv2
import numpy as np
import os
import time

# Çıkış klasörünü oluştur, eğer yoksa
output_folder = "./daire_yeni/"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Başlangıç parametreleri
torus_major_radius = 200
torus_minor_radius = 50
sphere_center_x = 400
sphere_center_y = 400
thickness = 2
angle_x = 0
angle_y = 0
scale = 1.0
img_size = (800, 800)

# Torus oluşturma fonksiyonu
def create_torus(major_radius, minor_radius, angle_x, angle_y, scale):
    phi, theta = np.mgrid[0:2 * np.pi:100j, 0:2 * np.pi:100j]
    x = (major_radius + minor_radius * np.cos(theta)) * np.cos(phi)
    y = (major_radius + minor_radius * np.cos(theta)) * np.sin(phi)
    z = minor_radius * np.sin(theta)

    # X ekseni etrafında dönme matrisi
    rotation_matrix_x = np.array([
        [1, 0, 0],
        [0, np.cos(np.radians(angle_x)), -np.sin(np.radians(angle_x))],
        [0, np.sin(np.radians(angle_x)), np.cos(np.radians(angle_x))]
    ])
    
    # Y ekseni etrafında dönme matrisi
    rotation_matrix_y = np.array([
        [np.cos(np.radians(angle_y)), 0, np.sin(np.radians(angle_y))],
        [0, 1, 0],
        [-np.sin(np.radians(angle_y)), 0, np.cos(np.radians(angle_y))]
    ])
    
    rotation_matrix = np.dot(rotation_matrix_y, rotation_matrix_x)
    
    x, y, z = np.dot(rotation_matrix, np.array([x.flatten(), y.flatten(), z.flatten()]))
    
    return x.reshape(theta.shape), y.reshape(theta.shape), z.reshape(theta.shape)

# Trackbar değişimlerinde çağrılacak işlev
def update_image(val):
    global torus_major_radius, torus_minor_radius, sphere_center_x, sphere_center_y, thickness, angle_x, angle_y, scale
    torus_major_radius = cv2.getTrackbarPos('Major Radius', 'Torus Drawer')
    torus_minor_radius = cv2.getTrackbarPos('Minor Radius', 'Torus Drawer')
    thickness = cv2.getTrackbarPos('Thickness', 'Torus Drawer')
    angle_x = cv2.getTrackbarPos('Angle X', 'Torus Drawer')
    angle_y = cv2.getTrackbarPos('Angle Y', 'Torus Drawer')
    scale = cv2.getTrackbarPos('Scale', 'Torus Drawer') / 10.0

    img = np.zeros((img_size[0], img_size[1], 3), dtype=np.uint8)

    x, y, z = create_torus(torus_major_radius * scale, torus_minor_radius * scale, angle_x, angle_y, scale)
    
    # Ekran koordinatlarına çevir
    x_screen = (x + sphere_center_x).astype(np.int32)
    y_screen = (y + sphere_center_y).astype(np.int32)

    # Noktaları görüntüye çiz
    for i in range(x_screen.shape[0]):
        for j in range(x_screen.shape[1]):
            cv2.circle(img, (x_screen[i, j], y_screen[i, j]), 1, (255, 255, 255), thickness)

    cv2.imshow('Torus Drawer', img)

# Pencere oluştur
cv2.namedWindow('Torus Drawer')

# Trackbarlar oluştur
cv2.createTrackbar('Major Radius', 'Torus Drawer', torus_major_radius, 300, update_image)
cv2.createTrackbar('Minor Radius', 'Torus Drawer', torus_minor_radius, 100, update_image)
cv2.createTrackbar('Thickness', 'Torus Drawer', thickness, 10, update_image)
cv2.createTrackbar('Angle X', 'Torus Drawer', angle_x, 360, update_image)
cv2.createTrackbar('Angle Y', 'Torus Drawer', angle_y, 360, update_image)
cv2.createTrackbar('Scale', 'Torus Drawer', int(scale * 10), 20, update_image)

# İlk görüntüyü oluştur
update_image(0)

# Kaydetme işlevi
def save_image():
    img = np.zeros((img_size[0], img_size[1], 3), dtype=np.uint8)
    x, y, z = create_torus(torus_major_radius * scale, torus_minor_radius * scale, angle_x, angle_y, scale)
    
    x_screen = (x + sphere_center_x).astype(np.int32)
    y_screen = (y + sphere_center_y).astype(np.int32)
    
    for i in range(x_screen.shape[0]):
        for j in range(x_screen.shape[1]):
            cv2.circle(img, (x_screen[i, j], y_screen[i, j]), 1, (255, 255, 255), thickness)
    
    filename = os.path.join(output_folder, f"Torus_{int(time.time())}.png")
    cv2.imwrite(filename, img)
    print(f"Image saved as {filename}")

# Zaman sayacı
last_save_time = time.time()

# Ana döngü
while True:
    current_time = time.time()
    key = cv2.waitKey(1)
    if key == ord('q'):
        break
    elif key == ord('s'):
        save_image()
    elif current_time - last_save_time >= 1:
        save_image()
        last_save_time = current_time

    update_image(0)

cv2.destroyAllWindows()
# Out:
# Image saved as ./daire_yeni/Torus_1718799072.png
# Image saved as ./daire_yeni/Torus_1718799073.png
# Image saved as ./daire_yeni/Torus_1718799074.png
# Image saved as ./daire_yeni/Torus_1718799074.png
# Image saved as ./daire_yeni/Torus_1718799075.png
# Image saved as ./daire_yeni/Torus_1718799075.png
# Image saved as ./daire_yeni/Torus_1718799075.png
# Image saved as ./daire_yeni/Torus_1718799075.png
# Image saved as ./daire_yeni/Torus_1718799076.png
# Image saved as ./daire_yeni/Torus_1718799077.png
# Image saved as ./daire_yeni/Torus_1718799078.png
# Image saved as ./daire_yeni/Torus_1718799079.png
# Image saved as ./daire_yeni/Torus_1718799080.png
# Image saved as ./daire_yeni/Torus_1718799081.png
# Image saved as ./daire_yeni/Torus_1718799082.png
# Image saved as ./daire_yeni/Torus_1718799083.png
# Image saved as ./daire_yeni/Torus_1718799084.png
# Image saved as ./daire_yeni/Torus_1718799085.png
# Image saved as ./daire_yeni/Torus_1718799086.png
# Image saved as ./daire_yeni/Torus_1718799087.png
# Image saved as ./daire_yeni/Torus_1718799088.png
# Image saved as ./daire_yeni/Torus_1718799089.png
# Image saved as ./daire_yeni/Torus_1718799090.png
# Image saved as ./daire_yeni/Torus_1718799091.png
# Image saved as ./daire_yeni/Torus_1718799092.png
# Image saved as ./daire_yeni/Torus_1718799093.png
# Image saved as ./daire_yeni/Torus_1718799094.png
# Image saved as ./daire_yeni/Torus_1718799095.png
# Image saved as ./daire_yeni/Torus_1718799096.png
# Image saved as ./daire_yeni/Torus_1718799097.png
# Image saved as ./daire_yeni/Torus_1718799098.png
# Image saved as ./daire_yeni/Torus_1718799099.png
# Image saved as ./daire_yeni/Torus_1718799100.png
# Image saved as ./daire_yeni/Torus_1718799101.png
# Image saved as ./daire_yeni/Torus_1718799102.png
# Image saved as ./daire_yeni/Torus_1718799103.png
# Image saved as ./daire_yeni/Torus_1718799104.png
# Image saved as ./daire_yeni/Torus_1718799105.png
# Image saved as ./daire_yeni/Torus_1718799106.png
# Image saved as ./daire_yeni/Torus_1718799106.png
# Image saved as ./daire_yeni/Torus_1718799107.png
# Image saved as ./daire_yeni/Torus_1718799107.png
# Image saved as ./daire_yeni/Torus_1718799107.png
# Image saved as ./daire_yeni/Torus_1718799107.png
# Image saved as ./daire_yeni/Torus_1718799108.png
# Image saved as ./daire_yeni/Torus_1718799108.png
# Image saved as ./daire_yeni/Torus_1718799109.png
# Image saved as ./daire_yeni/Torus_1718799110.png
# Image saved as ./daire_yeni/Torus_1718799111.png
# Image saved as ./daire_yeni/Torus_1718799111.png
# Image saved as ./daire_yeni/Torus_1718799111.png
# Image saved as ./daire_yeni/Torus_1718799111.png
# Image saved as ./daire_yeni/Torus_1718799112.png
# Image saved as ./daire_yeni/Torus_1718799112.png
# Image saved as ./daire_yeni/Torus_1718799112.png
# Image saved as ./daire_yeni/Torus_1718799113.png
# Image saved as ./daire_yeni/Torus_1718799113.png
# Image saved as ./daire_yeni/Torus_1718799113.png
# Image saved as ./daire_yeni/Torus_1718799113.png
# Image saved as ./daire_yeni/Torus_1718799114.png
# Image saved as ./daire_yeni/Torus_1718799114.png
# Image saved as ./daire_yeni/Torus_1718799114.png
# Image saved as ./daire_yeni/Torus_1718799115.png
# Image saved as ./daire_yeni/Torus_1718799115.png
# Image saved as ./daire_yeni/Torus_1718799115.png
# Image saved as ./daire_yeni/Torus_1718799116.png
# Image saved as ./daire_yeni/Torus_1718799116.png
# Image saved as ./daire_yeni/Torus_1718799117.png
# Image saved as ./daire_yeni/Torus_1718799117.png
# Image saved as ./daire_yeni/Torus_1718799118.png
# Image saved as ./daire_yeni/Torus_1718799118.png
# Image saved as ./daire_yeni/Torus_1718799118.png
# Image saved as ./daire_yeni/Torus_1718799119.png
# Image saved as ./daire_yeni/Torus_1718799120.png
# Image saved as ./daire_yeni/Torus_1718799121.png
# Image saved as ./daire_yeni/Torus_1718799122.png
# Image saved as ./daire_yeni/Torus_1718799123.png
# Image saved as ./daire_yeni/Torus_1718799124.png
# Image saved as ./daire_yeni/Torus_1718799125.png
# Image saved as ./daire_yeni/Torus_1718799126.png
# Image saved as ./daire_yeni/Torus_1718799127.png
# Image saved as ./daire_yeni/Torus_1718799128.png
# Image saved as ./daire_yeni/Torus_1718799129.png
# Image saved as ./daire_yeni/Torus_1718799130.png
# Image saved as ./daire_yeni/Torus_1718799131.png
# Image saved as ./daire_yeni/Torus_1718799131.png
# Image saved as ./daire_yeni/Torus_1718799132.png
# Image saved as ./daire_yeni/Torus_1718799132.png
# Image saved as ./daire_yeni/Torus_1718799132.png
# Image saved as ./daire_yeni/Torus_1718799132.png
# Image saved as ./daire_yeni/Torus_1718799132.png
# Image saved as ./daire_yeni/Torus_1718799132.png
# Image saved as ./daire_yeni/Torus_1718799133.png
# Image saved as ./daire_yeni/Torus_1718799133.png
# Image saved as ./daire_yeni/Torus_1718799133.png
# Image saved as ./daire_yeni/Torus_1718799133.png
# Image saved as ./daire_yeni/Torus_1718799133.png
# Image saved as ./daire_yeni/Torus_1718799134.png
# Image saved as ./daire_yeni/Torus_1718799134.png
# Image saved as ./daire_yeni/Torus_1718799134.png
# Image saved as ./daire_yeni/Torus_1718799134.png
# Image saved as ./daire_yeni/Torus_1718799134.png
# Image saved as ./daire_yeni/Torus_1718799135.png
# Image saved as ./daire_yeni/Torus_1718799135.png
# Image saved as ./daire_yeni/Torus_1718799135.png
# Image saved as ./daire_yeni/Torus_1718799136.png
# Image saved as ./daire_yeni/Torus_1718799136.png
# Image saved as ./daire_yeni/Torus_1718799137.png
# Image saved as ./daire_yeni/Torus_1718799137.png
# Image saved as ./daire_yeni/Torus_1718799137.png
# Image saved as ./daire_yeni/Torus_1718799137.png
# Image saved as ./daire_yeni/Torus_1718799138.png
# Image saved as ./daire_yeni/Torus_1718799138.png
# Image saved as ./daire_yeni/Torus_1718799138.png
# Image saved as ./daire_yeni/Torus_1718799138.png
# Image saved as ./daire_yeni/Torus_1718799138.png
# Image saved as ./daire_yeni/Torus_1718799139.png
# Image saved as ./daire_yeni/Torus_1718799139.png
# Image saved as ./daire_yeni/Torus_1718799139.png
# Image saved as ./daire_yeni/Torus_1718799139.png
# Image saved as ./daire_yeni/Torus_1718799140.png
# Image saved as ./daire_yeni/Torus_1718799140.png
# Image saved as ./daire_yeni/Torus_1718799140.png
# Image saved as ./daire_yeni/Torus_1718799140.png
# Image saved as ./daire_yeni/Torus_1718799140.png
# Image saved as ./daire_yeni/Torus_1718799141.png
# Image saved as ./daire_yeni/Torus_1718799141.png
# Image saved as ./daire_yeni/Torus_1718799141.png
# Image saved as ./daire_yeni/Torus_1718799141.png
# Image saved as ./daire_yeni/Torus_1718799142.png
# Image saved as ./daire_yeni/Torus_1718799143.png
# Image saved as ./daire_yeni/Torus_1718799143.png
# Image saved as ./daire_yeni/Torus_1718799143.png
# Image saved as ./daire_yeni/Torus_1718799143.png
# Image saved as ./daire_yeni/Torus_1718799143.png
# Image saved as ./daire_yeni/Torus_1718799144.png
# Image saved as ./daire_yeni/Torus_1718799144.png
# Image saved as ./daire_yeni/Torus_1718799144.png
# Image saved as ./daire_yeni/Torus_1718799144.png
# Image saved as ./daire_yeni/Torus_1718799144.png
# Image saved as ./daire_yeni/Torus_1718799145.png
# Image saved as ./daire_yeni/Torus_1718799145.png
# Image saved as ./daire_yeni/Torus_1718799145.png
# Image saved as ./daire_yeni/Torus_1718799145.png
# Image saved as ./daire_yeni/Torus_1718799145.png
# Image saved as ./daire_yeni/Torus_1718799145.png
# Image saved as ./daire_yeni/Torus_1718799146.png
# Image saved as ./daire_yeni/Torus_1718799147.png
# Image saved as ./daire_yeni/Torus_1718799148.png
# Image saved as ./daire_yeni/Torus_1718799149.png
# Image saved as ./daire_yeni/Torus_1718799150.png
# Image saved as ./daire_yeni/Torus_1718799151.png
# Image saved as ./daire_yeni/Torus_1718799152.png
# Image saved as ./daire_yeni/Torus_1718799152.png
# Image saved as ./daire_yeni/Torus_1718799152.png
# Image saved as ./daire_yeni/Torus_1718799152.png
# Image saved as ./daire_yeni/Torus_1718799152.png
# Image saved as ./daire_yeni/Torus_1718799153.png
# Image saved as ./daire_yeni/Torus_1718799153.png
# Image saved as ./daire_yeni/Torus_1718799153.png
# Image saved as ./daire_yeni/Torus_1718799153.png
# Image saved as ./daire_yeni/Torus_1718799153.png
# Image saved as ./daire_yeni/Torus_1718799153.png
# Image saved as ./daire_yeni/Torus_1718799154.png
# Image saved as ./daire_yeni/Torus_1718799154.png
# Image saved as ./daire_yeni/Torus_1718799154.png
# Image saved as ./daire_yeni/Torus_1718799154.png
# Image saved as ./daire_yeni/Torus_1718799154.png
# Image saved as ./daire_yeni/Torus_1718799154.png
# Image saved as ./daire_yeni/Torus_1718799155.png
# Image saved as ./daire_yeni/Torus_1718799156.png
# Image saved as ./daire_yeni/Torus_1718799157.png
# Image saved as ./daire_yeni/Torus_1718799157.png
# Image saved as ./daire_yeni/Torus_1718799157.png
# Image saved as ./daire_yeni/Torus_1718799157.png
# Image saved as ./daire_yeni/Torus_1718799157.png
# Image saved as ./daire_yeni/Torus_1718799158.png
# Image saved as ./daire_yeni/Torus_1718799158.png
# Image saved as ./daire_yeni/Torus_1718799158.png
# Image saved as ./daire_yeni/Torus_1718799158.png
# Image saved as ./daire_yeni/Torus_1718799158.png
# Image saved as ./daire_yeni/Torus_1718799158.png
# Image saved as ./daire_yeni/Torus_1718799160.png
# Image saved as ./daire_yeni/Torus_1718799161.png
# Image saved as ./daire_yeni/Torus_1718799161.png
# Image saved as ./daire_yeni/Torus_1718799161.png
# Image saved as ./daire_yeni/Torus_1718799161.png
# Image saved as ./daire_yeni/Torus_1718799161.png
# Image saved as ./daire_yeni/Torus_1718799162.png
# Image saved as ./daire_yeni/Torus_1718799162.png
# Image saved as ./daire_yeni/Torus_1718799162.png
# Image saved as ./daire_yeni/Torus_1718799162.png
# Image saved as ./daire_yeni/Torus_1718799162.png
# Image saved as ./daire_yeni/Torus_1718799162.png
# Image saved as ./daire_yeni/Torus_1718799162.png
# Image saved as ./daire_yeni/Torus_1718799163.png
# Image saved as ./daire_yeni/Torus_1718799163.png
# Image saved as ./daire_yeni/Torus_1718799163.png
# Image saved as ./daire_yeni/Torus_1718799163.png
# Image saved as ./daire_yeni/Torus_1718799163.png
# Image saved as ./daire_yeni/Torus_1718799164.png
# Image saved as ./daire_yeni/Torus_1718799164.png
# Image saved as ./daire_yeni/Torus_1718799164.png
# Image saved as ./daire_yeni/Torus_1718799164.png
# Image saved as ./daire_yeni/Torus_1718799164.png
# Image saved as ./daire_yeni/Torus_1718799164.png
# Image saved as ./daire_yeni/Torus_1718799164.png
# Image saved as ./daire_yeni/Torus_1718799165.png
# Image saved as ./daire_yeni/Torus_1718799165.png
# Image saved as ./daire_yeni/Torus_1718799165.png
# Image saved as ./daire_yeni/Torus_1718799165.png
# Image saved as ./daire_yeni/Torus_1718799165.png
# Image saved as ./daire_yeni/Torus_1718799165.png
# Image saved as ./daire_yeni/Torus_1718799166.png
# Image saved as ./daire_yeni/Torus_1718799167.png
# Image saved as ./daire_yeni/Torus_1718799167.png
# Image saved as ./daire_yeni/Torus_1718799168.png
# Image saved as ./daire_yeni/Torus_1718799169.png
# Image saved as ./daire_yeni/Torus_1718799170.png
# Image saved as ./daire_yeni/Torus_1718799171.png
# Image saved as ./daire_yeni/Torus_1718799172.png
# Image saved as ./daire_yeni/Torus_1718799173.png
# Image saved as ./daire_yeni/Torus_1718799174.png
# Image saved as ./daire_yeni/Torus_1718799175.png
# Image saved as ./daire_yeni/Torus_1718799175.png
# Image saved as ./daire_yeni/Torus_1718799176.png
# Image saved as ./daire_yeni/Torus_1718799177.png
# Image saved as ./daire_yeni/Torus_1718799178.png
# Image saved as ./daire_yeni/Torus_1718799179.png
# Image saved as ./daire_yeni/Torus_1718799180.png
# Image saved as ./daire_yeni/Torus_1718799180.png
# Image saved as ./daire_yeni/Torus_1718799180.png
# Image saved as ./daire_yeni/Torus_1718799180.png
# Image saved as ./daire_yeni/Torus_1718799180.png
# Image saved as ./daire_yeni/Torus_1718799181.png
# Image saved as ./daire_yeni/Torus_1718799181.png
# Image saved as ./daire_yeni/Torus_1718799181.png
# Image saved as ./daire_yeni/Torus_1718799181.png
# Image saved as ./daire_yeni/Torus_1718799182.png
# Image saved as ./daire_yeni/Torus_1718799182.png
# Image saved as ./daire_yeni/Torus_1718799182.png
# Image saved as ./daire_yeni/Torus_1718799182.png
# Image saved as ./daire_yeni/Torus_1718799182.png
# Image saved as ./daire_yeni/Torus_1718799182.png
# Image saved as ./daire_yeni/Torus_1718799183.png
# Image saved as ./daire_yeni/Torus_1718799183.png
# Image saved as ./daire_yeni/Torus_1718799183.png
# Image saved as ./daire_yeni/Torus_1718799183.png
# Image saved as ./daire_yeni/Torus_1718799183.png
# Image saved as ./daire_yeni/Torus_1718799184.png
# Image saved as ./daire_yeni/Torus_1718799184.png
# Image saved as ./daire_yeni/Torus_1718799184.png
# Image saved as ./daire_yeni/Torus_1718799184.png
# Image saved as ./daire_yeni/Torus_1718799184.png
# Image saved as ./daire_yeni/Torus_1718799185.png
# Image saved as ./daire_yeni/Torus_1718799185.png
# Image saved as ./daire_yeni/Torus_1718799185.png
# Image saved as ./daire_yeni/Torus_1718799185.png
# Image saved as ./daire_yeni/Torus_1718799185.png
# Image saved as ./daire_yeni/Torus_1718799185.png
# Image saved as ./daire_yeni/Torus_1718799186.png
# Image saved as ./daire_yeni/Torus_1718799186.png
# Image saved as ./daire_yeni/Torus_1718799186.png
# Image saved as ./daire_yeni/Torus_1718799186.png
# Image saved as ./daire_yeni/Torus_1718799186.png
# Image saved as ./daire_yeni/Torus_1718799186.png
# Image saved as ./daire_yeni/Torus_1718799186.png
# Image saved as ./daire_yeni/Torus_1718799187.png
# Image saved as ./daire_yeni/Torus_1718799187.png
# Image saved as ./daire_yeni/Torus_1718799187.png
# Image saved as ./daire_yeni/Torus_1718799188.png
# Image saved as ./daire_yeni/Torus_1718799188.png
# Image saved as ./daire_yeni/Torus_1718799188.png
# Image saved as ./daire_yeni/Torus_1718799188.png
# Image saved as ./daire_yeni/Torus_1718799188.png
# Image saved as ./daire_yeni/Torus_1718799188.png
# Image saved as ./daire_yeni/Torus_1718799189.png
# Image saved as ./daire_yeni/Torus_1718799189.png
# Image saved as ./daire_yeni/Torus_1718799189.png
# Image saved as ./daire_yeni/Torus_1718799189.png
# Image saved as ./daire_yeni/Torus_1718799190.png
# Image saved as ./daire_yeni/Torus_1718799191.png
# Image saved as ./daire_yeni/Torus_1718799192.png
# Image saved as ./daire_yeni/Torus_1718799193.png
# Image saved as ./daire_yeni/Torus_1718799194.png
# Image saved as ./daire_yeni/Torus_1718799195.png
# Image saved as ./daire_yeni/Torus_1718799196.png
# Image saved as ./daire_yeni/Torus_1718799197.png
# Image saved as ./daire_yeni/Torus_1718799199.png
# Image saved as ./daire_yeni/Torus_1718799200.png
# Image saved as ./daire_yeni/Torus_1718799201.png
# Image saved as ./daire_yeni/Torus_1718799202.png
# Image saved as ./daire_yeni/Torus_1718799203.png
# Image saved as ./daire_yeni/Torus_1718799204.png
# Image saved as ./daire_yeni/Torus_1718799205.png
# Image saved as ./daire_yeni/Torus_1718799206.png
# Image saved as ./daire_yeni/Torus_1718799207.png
# Image saved as ./daire_yeni/Torus_1718799208.png
# Image saved as ./daire_yeni/Torus_1718799209.png
# Image saved as ./daire_yeni/Torus_1718799210.png
# Image saved as ./daire_yeni/Torus_1718799210.png
# Image saved as ./daire_yeni/Torus_1718799210.png
# Image saved as ./daire_yeni/Torus_1718799210.png
# Image saved as ./daire_yeni/Torus_1718799210.png
# Image saved as ./daire_yeni/Torus_1718799211.png
# Image saved as ./daire_yeni/Torus_1718799211.png
# Image saved as ./daire_yeni/Torus_1718799211.png
# Image saved as ./daire_yeni/Torus_1718799211.png
# Image saved as ./daire_yeni/Torus_1718799211.png
# Image saved as ./daire_yeni/Torus_1718799212.png
# Image saved as ./daire_yeni/Torus_1718799212.png
# Image saved as ./daire_yeni/Torus_1718799212.png
# Image saved as ./daire_yeni/Torus_1718799212.png
# Image saved as ./daire_yeni/Torus_1718799212.png
# Image saved as ./daire_yeni/Torus_1718799213.png
# Image saved as ./daire_yeni/Torus_1718799213.png
# Image saved as ./daire_yeni/Torus_1718799213.png
# Image saved as ./daire_yeni/Torus_1718799213.png
# Image saved as ./daire_yeni/Torus_1718799214.png
# Image saved as ./daire_yeni/Torus_1718799214.png
# Image saved as ./daire_yeni/Torus_1718799214.png
# Image saved as ./daire_yeni/Torus_1718799214.png
# Image saved as ./daire_yeni/Torus_1718799214.png
# Image saved as ./daire_yeni/Torus_1718799214.png
# Image saved as ./daire_yeni/Torus_1718799214.png
# Image saved as ./daire_yeni/Torus_1718799215.png
# Image saved as ./daire_yeni/Torus_1718799215.png
# Image saved as ./daire_yeni/Torus_1718799215.png
# Image saved as ./daire_yeni/Torus_1718799215.png
# Image saved as ./daire_yeni/Torus_1718799215.png
# Image saved as ./daire_yeni/Torus_1718799215.png
# Image saved as ./daire_yeni/Torus_1718799215.png
# Image saved as ./daire_yeni/Torus_1718799216.png
# Image saved as ./daire_yeni/Torus_1718799216.png
# Image saved as ./daire_yeni/Torus_1718799216.png
# Image saved as ./daire_yeni/Torus_1718799217.png
# Image saved as ./daire_yeni/Torus_1718799218.png
# Image saved as ./daire_yeni/Torus_1718799219.png
# Image saved as ./daire_yeni/Torus_1718799220.png
# Image saved as ./daire_yeni/Torus_1718799221.png
# Image saved as ./daire_yeni/Torus_1718799222.png
# Image saved as ./daire_yeni/Torus_1718799223.png
# Image saved as ./daire_yeni/Torus_1718799224.png
# Image saved as ./daire_yeni/Torus_1718799225.png
# Image saved as ./daire_yeni/Torus_1718799226.png
# Image saved as ./daire_yeni/Torus_1718799227.png
# Image saved as ./daire_yeni/Torus_1718799228.png
# Image saved as ./daire_yeni/Torus_1718799229.png
# Image saved as ./daire_yeni/Torus_1718799230.png
# Image saved as ./daire_yeni/Torus_1718799231.png
# Image saved as ./daire_yeni/Torus_1718799232.png
# Image saved as ./daire_yeni/Torus_1718799233.png
# Image saved as ./daire_yeni/Torus_1718799234.png
# Image saved as ./daire_yeni/Torus_1718799235.png
# Image saved as ./daire_yeni/Torus_1718799236.png
# Image saved as ./daire_yeni/Torus_1718799237.png
# Image saved as ./daire_yeni/Torus_1718799238.png
# Image saved as ./daire_yeni/Torus_1718799238.png
# Image saved as ./daire_yeni/Torus_1718799239.png
# Image saved as ./daire_yeni/Torus_1718799239.png
# Image saved as ./daire_yeni/Torus_1718799240.png
# Image saved as ./daire_yeni/Torus_1718799240.png
# Image saved as ./daire_yeni/Torus_1718799241.png
# Image saved as ./daire_yeni/Torus_1718799241.png
# Image saved as ./daire_yeni/Torus_1718799241.png
# Image saved as ./daire_yeni/Torus_1718799241.png
# Image saved as ./daire_yeni/Torus_1718799241.png
# Image saved as ./daire_yeni/Torus_1718799241.png
# Image saved as ./daire_yeni/Torus_1718799242.png
# Image saved as ./daire_yeni/Torus_1718799242.png
# Image saved as ./daire_yeni/Torus_1718799242.png
# Image saved as ./daire_yeni/Torus_1718799242.png
# Image saved as ./daire_yeni/Torus_1718799243.png
# Image saved as ./daire_yeni/Torus_1718799243.png
# Image saved as ./daire_yeni/Torus_1718799244.png
# Image saved as ./daire_yeni/Torus_1718799244.png
# Image saved as ./daire_yeni/Torus_1718799244.png
# Image saved as ./daire_yeni/Torus_1718799244.png
# Image saved as ./daire_yeni/Torus_1718799244.png
# Image saved as ./daire_yeni/Torus_1718799245.png
# Image saved as ./daire_yeni/Torus_1718799245.png
# Image saved as ./daire_yeni/Torus_1718799245.png
# Image saved as ./daire_yeni/Torus_1718799245.png
# Image saved as ./daire_yeni/Torus_1718799245.png
# Image saved as ./daire_yeni/Torus_1718799245.png
# Image saved as ./daire_yeni/Torus_1718799245.png
# Image saved as ./daire_yeni/Torus_1718799246.png
# Image saved as ./daire_yeni/Torus_1718799246.png
# Image saved as ./daire_yeni/Torus_1718799246.png
# Image saved as ./daire_yeni/Torus_1718799246.png
# Image saved as ./daire_yeni/Torus_1718799246.png
# Image saved as ./daire_yeni/Torus_1718799246.png
# Image saved as ./daire_yeni/Torus_1718799247.png
# Image saved as ./daire_yeni/Torus_1718799247.png
# Image saved as ./daire_yeni/Torus_1718799247.png
# Image saved as ./daire_yeni/Torus_1718799247.png
# Image saved as ./daire_yeni/Torus_1718799247.png
# Image saved as ./daire_yeni/Torus_1718799247.png
# Image saved as ./daire_yeni/Torus_1718799248.png
# Image saved as ./daire_yeni/Torus_1718799248.png
# Image saved as ./daire_yeni/Torus_1718799248.png
# Image saved as ./daire_yeni/Torus_1718799248.png
# Image saved as ./daire_yeni/Torus_1718799248.png
# Image saved as ./daire_yeni/Torus_1718799249.png
# Image saved as ./daire_yeni/Torus_1718799249.png
# Image saved as ./daire_yeni/Torus_1718799249.png
# Image saved as ./daire_yeni/Torus_1718799249.png
# Image saved as ./daire_yeni/Torus_1718799249.png
# Image saved as ./daire_yeni/Torus_1718799249.png
# Image saved as ./daire_yeni/Torus_1718799250.png
# Image saved as ./daire_yeni/Torus_1718799250.png
# Image saved as ./daire_yeni/Torus_1718799250.png
# Image saved as ./daire_yeni/Torus_1718799250.png
# Image saved as ./daire_yeni/Torus_1718799250.png
# Image saved as ./daire_yeni/Torus_1718799251.png
# Image saved as ./daire_yeni/Torus_1718799251.png
# Image saved as ./daire_yeni/Torus_1718799251.png
# Image saved as ./daire_yeni/Torus_1718799251.png
# Image saved as ./daire_yeni/Torus_1718799251.png
# Image saved as ./daire_yeni/Torus_1718799251.png
# Image saved as ./daire_yeni/Torus_1718799252.png
# Image saved as ./daire_yeni/Torus_1718799252.png
# Image saved as ./daire_yeni/Torus_1718799253.png
# Image saved as ./daire_yeni/Torus_1718799253.png
# Image saved as ./daire_yeni/Torus_1718799253.png
# Image saved as ./daire_yeni/Torus_1718799253.png
# Image saved as ./daire_yeni/Torus_1718799253.png
# Image saved as ./daire_yeni/Torus_1718799253.png
# Image saved as ./daire_yeni/Torus_1718799253.png
# Image saved as ./daire_yeni/Torus_1718799254.png
# Image saved as ./daire_yeni/Torus_1718799254.png
# Image saved as ./daire_yeni/Torus_1718799255.png
# Image saved as ./daire_yeni/Torus_1718799256.png
# Image saved as ./daire_yeni/Torus_1718799257.png
# Image saved as ./daire_yeni/Torus_1718799258.png
# Image saved as ./daire_yeni/Torus_1718799259.png
# Image saved as ./daire_yeni/Torus_1718799260.png
# Image saved as ./daire_yeni/Torus_1718799260.png
# Image saved as ./daire_yeni/Torus_1718799261.png
# Image saved as ./daire_yeni/Torus_1718799261.png
# Image saved as ./daire_yeni/Torus_1718799261.png
# Image saved as ./daire_yeni/Torus_1718799261.png
# Image saved as ./daire_yeni/Torus_1718799261.png
# Image saved as ./daire_yeni/Torus_1718799261.png
# Image saved as ./daire_yeni/Torus_1718799262.png
# Image saved as ./daire_yeni/Torus_1718799262.png
# Image saved as ./daire_yeni/Torus_1718799262.png
# Image saved as ./daire_yeni/Torus_1718799262.png
# Image saved as ./daire_yeni/Torus_1718799262.png
# Image saved as ./daire_yeni/Torus_1718799262.png
# Image saved as ./daire_yeni/Torus_1718799263.png
# Image saved as ./daire_yeni/Torus_1718799263.png
# Image saved as ./daire_yeni/Torus_1718799263.png
# Image saved as ./daire_yeni/Torus_1718799263.png
# Image saved as ./daire_yeni/Torus_1718799264.png
# Image saved as ./daire_yeni/Torus_1718799265.png
# Image saved as ./daire_yeni/Torus_1718799266.png
# Image saved as ./daire_yeni/Torus_1718799267.png
# Image saved as ./daire_yeni/Torus_1718799267.png
# Image saved as ./daire_yeni/Torus_1718799267.png
# Image saved as ./daire_yeni/Torus_1718799268.png
# Image saved as ./daire_yeni/Torus_1718799268.png
# Image saved as ./daire_yeni/Torus_1718799269.png
# Image saved as ./daire_yeni/Torus_1718799269.png
# Image saved as ./daire_yeni/Torus_1718799269.png
# Image saved as ./daire_yeni/Torus_1718799269.png
# Image saved as ./daire_yeni/Torus_1718799269.png
# Image saved as ./daire_yeni/Torus_1718799269.png
# Image saved as ./daire_yeni/Torus_1718799269.png
# Image saved as ./daire_yeni/Torus_1718799269.png
# Image saved as ./daire_yeni/Torus_1718799270.png
# Image saved as ./daire_yeni/Torus_1718799270.png
# Image saved as ./daire_yeni/Torus_1718799270.png
# Image saved as ./daire_yeni/Torus_1718799270.png
# Image saved as ./daire_yeni/Torus_1718799270.png
# Image saved as ./daire_yeni/Torus_1718799270.png
# Image saved as ./daire_yeni/Torus_1718799271.png
# Image saved as ./daire_yeni/Torus_1718799271.png
# Image saved as ./daire_yeni/Torus_1718799271.png
# Image saved as ./daire_yeni/Torus_1718799271.png
# Image saved as ./daire_yeni/Torus_1718799271.png
# Image saved as ./daire_yeni/Torus_1718799271.png
# Image saved as ./daire_yeni/Torus_1718799272.png
# Image saved as ./daire_yeni/Torus_1718799272.png
# Image saved as ./daire_yeni/Torus_1718799272.png
# Image saved as ./daire_yeni/Torus_1718799272.png
# Image saved as ./daire_yeni/Torus_1718799272.png
# Image saved as ./daire_yeni/Torus_1718799272.png
# Image saved as ./daire_yeni/Torus_1718799272.png
# Image saved as ./daire_yeni/Torus_1718799273.png
# Image saved as ./daire_yeni/Torus_1718799273.png
# Image saved as ./daire_yeni/Torus_1718799273.png
# Image saved as ./daire_yeni/Torus_1718799273.png
# Image saved as ./daire_yeni/Torus_1718799273.png
# Image saved as ./daire_yeni/Torus_1718799273.png
# Image saved as ./daire_yeni/Torus_1718799273.png
# Image saved as ./daire_yeni/Torus_1718799274.png
# Image saved as ./daire_yeni/Torus_1718799274.png
# Image saved as ./daire_yeni/Torus_1718799274.png
# Image saved as ./daire_yeni/Torus_1718799274.png
# Image saved as ./daire_yeni/Torus_1718799274.png
# Image saved as ./daire_yeni/Torus_1718799274.png
# Image saved as ./daire_yeni/Torus_1718799275.png
# Image saved as ./daire_yeni/Torus_1718799275.png
# Image saved as ./daire_yeni/Torus_1718799275.png
# Image saved as ./daire_yeni/Torus_1718799275.png
# Image saved as ./daire_yeni/Torus_1718799275.png
# Image saved as ./daire_yeni/Torus_1718799275.png
# Image saved as ./daire_yeni/Torus_1718799275.png
# Image saved as ./daire_yeni/Torus_1718799276.png
# Image saved as ./daire_yeni/Torus_1718799276.png
# Image saved as ./daire_yeni/Torus_1718799276.png
# Image saved as ./daire_yeni/Torus_1718799276.png
# Image saved as ./daire_yeni/Torus_1718799276.png
# Image saved as ./daire_yeni/Torus_1718799276.png
# Image saved as ./daire_yeni/Torus_1718799277.png
# Image saved as ./daire_yeni/Torus_1718799277.png
# Image saved as ./daire_yeni/Torus_1718799277.png
# Image saved as ./daire_yeni/Torus_1718799277.png
# Image saved as ./daire_yeni/Torus_1718799277.png
# Image saved as ./daire_yeni/Torus_1718799277.png
# Image saved as ./daire_yeni/Torus_1718799278.png
# Image saved as ./daire_yeni/Torus_1718799278.png
# Image saved as ./daire_yeni/Torus_1718799278.png
# Image saved as ./daire_yeni/Torus_1718799278.png
# Image saved as ./daire_yeni/Torus_1718799278.png
# Image saved as ./daire_yeni/Torus_1718799278.png
# Image saved as ./daire_yeni/Torus_1718799278.png
# Image saved as ./daire_yeni/Torus_1718799279.png
# Image saved as ./daire_yeni/Torus_1718799279.png
# Image saved as ./daire_yeni/Torus_1718799279.png
# Image saved as ./daire_yeni/Torus_1718799279.png
# Image saved as ./daire_yeni/Torus_1718799279.png
# Image saved as ./daire_yeni/Torus_1718799279.png
# Image saved as ./daire_yeni/Torus_1718799279.png
# Image saved as ./daire_yeni/Torus_1718799280.png
# Image saved as ./daire_yeni/Torus_1718799280.png
# Image saved as ./daire_yeni/Torus_1718799280.png
# Image saved as ./daire_yeni/Torus_1718799280.png
# Image saved as ./daire_yeni/Torus_1718799280.png
# Image saved as ./daire_yeni/Torus_1718799280.png
# Image saved as ./daire_yeni/Torus_1718799281.png
# Image saved as ./daire_yeni/Torus_1718799281.png
# Image saved as ./daire_yeni/Torus_1718799281.png
# Image saved as ./daire_yeni/Torus_1718799281.png
# Image saved as ./daire_yeni/Torus_1718799281.png
# Image saved as ./daire_yeni/Torus_1718799281.png
# Image saved as ./daire_yeni/Torus_1718799282.png
# Image saved as ./daire_yeni/Torus_1718799282.png
# Image saved as ./daire_yeni/Torus_1718799282.png
# Image saved as ./daire_yeni/Torus_1718799282.png
# Image saved as ./daire_yeni/Torus_1718799283.png
# Image saved as ./daire_yeni/Torus_1718799283.png
# Image saved as ./daire_yeni/Torus_1718799283.png
# Image saved as ./daire_yeni/Torus_1718799284.png
# Image saved as ./daire_yeni/Torus_1718799284.png
# Image saved as ./daire_yeni/Torus_1718799284.png
# Image saved as ./daire_yeni/Torus_1718799284.png
# Image saved as ./daire_yeni/Torus_1718799284.png
# Image saved as ./daire_yeni/Torus_1718799284.png
# Image saved as ./daire_yeni/Torus_1718799284.png
# Image saved as ./daire_yeni/Torus_1718799285.png
# Image saved as ./daire_yeni/Torus_1718799285.png
# Image saved as ./daire_yeni/Torus_1718799285.png
# Image saved as ./daire_yeni/Torus_1718799285.png
# Image saved as ./daire_yeni/Torus_1718799285.png
# Image saved as ./daire_yeni/Torus_1718799285.png
# Image saved as ./daire_yeni/Torus_1718799286.png
# Image saved as ./daire_yeni/Torus_1718799286.png
# Image saved as ./daire_yeni/Torus_1718799286.png
# Image saved as ./daire_yeni/Torus_1718799286.png
# Image saved as ./daire_yeni/Torus_1718799286.png
# Image saved as ./daire_yeni/Torus_1718799286.png
# Image saved as ./daire_yeni/Torus_1718799286.png
# Image saved as ./daire_yeni/Torus_1718799287.png
# Image saved as ./daire_yeni/Torus_1718799287.png
# Image saved as ./daire_yeni/Torus_1718799287.png
# Image saved as ./daire_yeni/Torus_1718799287.png
# Image saved as ./daire_yeni/Torus_1718799287.png
# Image saved as ./daire_yeni/Torus_1718799287.png
# Image saved as ./daire_yeni/Torus_1718799288.png
# Image saved as ./daire_yeni/Torus_1718799288.png
# Image saved as ./daire_yeni/Torus_1718799288.png
# Image saved as ./daire_yeni/Torus_1718799288.png
# Image saved as ./daire_yeni/Torus_1718799288.png
# Image saved as ./daire_yeni/Torus_1718799288.png
# Image saved as ./daire_yeni/Torus_1718799288.png
# Image saved as ./daire_yeni/Torus_1718799289.png
# Image saved as ./daire_yeni/Torus_1718799289.png
# Image saved as ./daire_yeni/Torus_1718799289.png
# Image saved as ./daire_yeni/Torus_1718799289.png
# Image saved as ./daire_yeni/Torus_1718799289.png
# Image saved as ./daire_yeni/Torus_1718799289.png
# Image saved as ./daire_yeni/Torus_1718799290.png
# Image saved as ./daire_yeni/Torus_1718799290.png
# Image saved as ./daire_yeni/Torus_1718799290.png
# Image saved as ./daire_yeni/Torus_1718799290.png
# Image saved as ./daire_yeni/Torus_1718799290.png
# Image saved as ./daire_yeni/Torus_1718799290.png
# Image saved as ./daire_yeni/Torus_1718799291.png
# Image saved as ./daire_yeni/Torus_1718799291.png
# Image saved as ./daire_yeni/Torus_1718799291.png
# Image saved as ./daire_yeni/Torus_1718799291.png
# Image saved as ./daire_yeni/Torus_1718799291.png
# Image saved as ./daire_yeni/Torus_1718799292.png
# Image saved as ./daire_yeni/Torus_1718799292.png
# Image saved as ./daire_yeni/Torus_1718799293.png
# Image saved as ./daire_yeni/Torus_1718799294.png
# Image saved as ./daire_yeni/Torus_1718799295.png
# Image saved as ./daire_yeni/Torus_1718799296.png
# Image saved as ./daire_yeni/Torus_1718799297.png
# Image saved as ./daire_yeni/Torus_1718799298.png
# Image saved as ./daire_yeni/Torus_1718799298.png
# Image saved as ./daire_yeni/Torus_1718799298.png
# Image saved as ./daire_yeni/Torus_1718799298.png
# Image saved as ./daire_yeni/Torus_1718799299.png
# Image saved as ./daire_yeni/Torus_1718799299.png
# Image saved as ./daire_yeni/Torus_1718799299.png
# Image saved as ./daire_yeni/Torus_1718799299.png
# Image saved as ./daire_yeni/Torus_1718799299.png
# Image saved as ./daire_yeni/Torus_1718799299.png
# Image saved as ./daire_yeni/Torus_1718799300.png
# Image saved as ./daire_yeni/Torus_1718799300.png
# Image saved as ./daire_yeni/Torus_1718799300.png
# Image saved as ./daire_yeni/Torus_1718799300.png
# Image saved as ./daire_yeni/Torus_1718799300.png
# Image saved as ./daire_yeni/Torus_1718799301.png
# Image saved as ./daire_yeni/Torus_1718799301.png
# Image saved as ./daire_yeni/Torus_1718799301.png
# Image saved as ./daire_yeni/Torus_1718799301.png
# Image saved as ./daire_yeni/Torus_1718799301.png
# Image saved as ./daire_yeni/Torus_1718799301.png
# Image saved as ./daire_yeni/Torus_1718799301.png
# Image saved as ./daire_yeni/Torus_1718799302.png
# Image saved as ./daire_yeni/Torus_1718799302.png
# Image saved as ./daire_yeni/Torus_1718799302.png
# Image saved as ./daire_yeni/Torus_1718799302.png
# Image saved as ./daire_yeni/Torus_1718799302.png
# Image saved as ./daire_yeni/Torus_1718799302.png
# Image saved as ./daire_yeni/Torus_1718799302.png
# Image saved as ./daire_yeni/Torus_1718799303.png
# Image saved as ./daire_yeni/Torus_1718799303.png
# Image saved as ./daire_yeni/Torus_1718799303.png
# Image saved as ./daire_yeni/Torus_1718799303.png
# Image saved as ./daire_yeni/Torus_1718799303.png
# Image saved as ./daire_yeni/Torus_1718799303.png
# Image saved as ./daire_yeni/Torus_1718799303.png
# Image saved as ./daire_yeni/Torus_1718799304.png
# Image saved as ./daire_yeni/Torus_1718799304.png
# Image saved as ./daire_yeni/Torus_1718799304.png
# Image saved as ./daire_yeni/Torus_1718799304.png
# Image saved as ./daire_yeni/Torus_1718799304.png
# Image saved as ./daire_yeni/Torus_1718799304.png
# Image saved as ./daire_yeni/Torus_1718799304.png
# Image saved as ./daire_yeni/Torus_1718799305.png
# Image saved as ./daire_yeni/Torus_1718799305.png
# Image saved as ./daire_yeni/Torus_1718799305.png
# Image saved as ./daire_yeni/Torus_1718799305.png
# Image saved as ./daire_yeni/Torus_1718799305.png
# Image saved as ./daire_yeni/Torus_1718799305.png
# Image saved as ./daire_yeni/Torus_1718799306.png
# Image saved as ./daire_yeni/Torus_1718799306.png
# Image saved as ./daire_yeni/Torus_1718799306.png
# Image saved as ./daire_yeni/Torus_1718799306.png
# Image saved as ./daire_yeni/Torus_1718799306.png
# Image saved as ./daire_yeni/Torus_1718799306.png
# Image saved as ./daire_yeni/Torus_1718799306.png
# Image saved as ./daire_yeni/Torus_1718799307.png
# Image saved as ./daire_yeni/Torus_1718799307.png
# Image saved as ./daire_yeni/Torus_1718799307.png
# Image saved as ./daire_yeni/Torus_1718799307.png
# Image saved as ./daire_yeni/Torus_1718799307.png
# Image saved as ./daire_yeni/Torus_1718799307.png
# Image saved as ./daire_yeni/Torus_1718799307.png
# Image saved as ./daire_yeni/Torus_1718799308.png
# Image saved as ./daire_yeni/Torus_1718799308.png
# Image saved as ./daire_yeni/Torus_1718799308.png
# Image saved as ./daire_yeni/Torus_1718799308.png
# Image saved as ./daire_yeni/Torus_1718799309.png
# Image saved as ./daire_yeni/Torus_1718799309.png
# Image saved as ./daire_yeni/Torus_1718799309.png
# Image saved as ./daire_yeni/Torus_1718799309.png
# Image saved as ./daire_yeni/Torus_1718799309.png
# Image saved as ./daire_yeni/Torus_1718799310.png
# Image saved as ./daire_yeni/Torus_1718799310.png
# Image saved as ./daire_yeni/Torus_1718799310.png
# Image saved as ./daire_yeni/Torus_1718799310.png
# Image saved as ./daire_yeni/Torus_1718799310.png
# Image saved as ./daire_yeni/Torus_1718799310.png
# Image saved as ./daire_yeni/Torus_1718799310.png
# Image saved as ./daire_yeni/Torus_1718799311.png
# Image saved as ./daire_yeni/Torus_1718799311.png
# Image saved as ./daire_yeni/Torus_1718799311.png
# Image saved as ./daire_yeni/Torus_1718799311.png
# Image saved as ./daire_yeni/Torus_1718799311.png
# Image saved as ./daire_yeni/Torus_1718799311.png
# Image saved as ./daire_yeni/Torus_1718799312.png
# Image saved as ./daire_yeni/Torus_1718799312.png
# Image saved as ./daire_yeni/Torus_1718799312.png
# Image saved as ./daire_yeni/Torus_1718799312.png
# Image saved as ./daire_yeni/Torus_1718799312.png
# Image saved as ./daire_yeni/Torus_1718799313.png
# Image saved as ./daire_yeni/Torus_1718799314.png
# Image saved as ./daire_yeni/Torus_1718799315.png
# Image saved as ./daire_yeni/Torus_1718799316.png
# Image saved as ./daire_yeni/Torus_1718799317.png
# Image saved as ./daire_yeni/Torus_1718799317.png
# Image saved as ./daire_yeni/Torus_1718799317.png
# Image saved as ./daire_yeni/Torus_1718799317.png
# Image saved as ./daire_yeni/Torus_1718799317.png
# Image saved as ./daire_yeni/Torus_1718799317.png
# Image saved as ./daire_yeni/Torus_1718799318.png
# Image saved as ./daire_yeni/Torus_1718799318.png
# Image saved as ./daire_yeni/Torus_1718799318.png
# Image saved as ./daire_yeni/Torus_1718799318.png
# Image saved as ./daire_yeni/Torus_1718799318.png
# Image saved as ./daire_yeni/Torus_1718799318.png
# Image saved as ./daire_yeni/Torus_1718799318.png
# Image saved as ./daire_yeni/Torus_1718799319.png
# Image saved as ./daire_yeni/Torus_1718799319.png
# Image saved as ./daire_yeni/Torus_1718799319.png
# Image saved as ./daire_yeni/Torus_1718799319.png
# Image saved as ./daire_yeni/Torus_1718799319.png
# Image saved as ./daire_yeni/Torus_1718799319.png
# Image saved as ./daire_yeni/Torus_1718799320.png
# Image saved as ./daire_yeni/Torus_1718799320.png
# Image saved as ./daire_yeni/Torus_1718799320.png
# Image saved as ./daire_yeni/Torus_1718799320.png
# Image saved as ./daire_yeni/Torus_1718799320.png
# Image saved as ./daire_yeni/Torus_1718799320.png
# Image saved as ./daire_yeni/Torus_1718799321.png
# Image saved as ./daire_yeni/Torus_1718799321.png
# Image saved as ./daire_yeni/Torus_1718799321.png
# Image saved as ./daire_yeni/Torus_1718799321.png
# Image saved as ./daire_yeni/Torus_1718799321.png
# Image saved as ./daire_yeni/Torus_1718799321.png
# Image saved as ./daire_yeni/Torus_1718799321.png
# Image saved as ./daire_yeni/Torus_1718799322.png
# Image saved as ./daire_yeni/Torus_1718799322.png
# Image saved as ./daire_yeni/Torus_1718799322.png
# Image saved as ./daire_yeni/Torus_1718799322.png
# Image saved as ./daire_yeni/Torus_1718799322.png
# Image saved as ./daire_yeni/Torus_1718799322.png
# Image saved as ./daire_yeni/Torus_1718799323.png
# Image saved as ./daire_yeni/Torus_1718799323.png
# Image saved as ./daire_yeni/Torus_1718799323.png
# Image saved as ./daire_yeni/Torus_1718799323.png
# Image saved as ./daire_yeni/Torus_1718799323.png
# Image saved as ./daire_yeni/Torus_1718799323.png
# Image saved as ./daire_yeni/Torus_1718799323.png
# Image saved as ./daire_yeni/Torus_1718799324.png
# Image saved as ./daire_yeni/Torus_1718799324.png
# Image saved as ./daire_yeni/Torus_1718799324.png
# Image saved as ./daire_yeni/Torus_1718799324.png
# Image saved as ./daire_yeni/Torus_1718799324.png
# Image saved as ./daire_yeni/Torus_1718799324.png
# Image saved as ./daire_yeni/Torus_1718799325.png
# Image saved as ./daire_yeni/Torus_1718799325.png
# Image saved as ./daire_yeni/Torus_1718799325.png
# Image saved as ./daire_yeni/Torus_1718799325.png
# Image saved as ./daire_yeni/Torus_1718799325.png
# Image saved as ./daire_yeni/Torus_1718799326.png
# Image saved as ./daire_yeni/Torus_1718799326.png
# Image saved as ./daire_yeni/Torus_1718799326.png
# Image saved as ./daire_yeni/Torus_1718799326.png
# Image saved as ./daire_yeni/Torus_1718799326.png
# Image saved as ./daire_yeni/Torus_1718799326.png
# Image saved as ./daire_yeni/Torus_1718799327.png
# Image saved as ./daire_yeni/Torus_1718799327.png
# Image saved as ./daire_yeni/Torus_1718799327.png
# Image saved as ./daire_yeni/Torus_1718799327.png
# Image saved as ./daire_yeni/Torus_1718799327.png
# Image saved as ./daire_yeni/Torus_1718799327.png
# Image saved as ./daire_yeni/Torus_1718799327.png
# Image saved as ./daire_yeni/Torus_1718799328.png
# Image saved as ./daire_yeni/Torus_1718799328.png
# Image saved as ./daire_yeni/Torus_1718799328.png
# Image saved as ./daire_yeni/Torus_1718799328.png
# Image saved as ./daire_yeni/Torus_1718799328.png
# Image saved as ./daire_yeni/Torus_1718799329.png
# Image saved as ./daire_yeni/Torus_1718799330.png
# Image saved as ./daire_yeni/Torus_1718799331.png
# Image saved as ./daire_yeni/Torus_1718799331.png
# Image saved as ./daire_yeni/Torus_1718799331.png
# Image saved as ./daire_yeni/Torus_1718799332.png
# Image saved as ./daire_yeni/Torus_1718799333.png
# Image saved as ./daire_yeni/Torus_1718799334.png
# Image saved as ./daire_yeni/Torus_1718799335.png
# Image saved as ./daire_yeni/Torus_1718799335.png
# Image saved as ./daire_yeni/Torus_1718799335.png
# Image saved as ./daire_yeni/Torus_1718799335.png
# Image saved as ./daire_yeni/Torus_1718799335.png
# Image saved as ./daire_yeni/Torus_1718799335.png
# Image saved as ./daire_yeni/Torus_1718799336.png
# Image saved as ./daire_yeni/Torus_1718799336.png
# Image saved as ./daire_yeni/Torus_1718799336.png
# Image saved as ./daire_yeni/Torus_1718799336.png
# Image saved as ./daire_yeni/Torus_1718799336.png
# Image saved as ./daire_yeni/Torus_1718799336.png
# Image saved as ./daire_yeni/Torus_1718799336.png
# Image saved as ./daire_yeni/Torus_1718799337.png
# Image saved as ./daire_yeni/Torus_1718799337.png
# Image saved as ./daire_yeni/Torus_1718799337.png
# Image saved as ./daire_yeni/Torus_1718799337.png
# Image saved as ./daire_yeni/Torus_1718799338.png
# Image saved as ./daire_yeni/Torus_1718799338.png
# Image saved as ./daire_yeni/Torus_1718799338.png
# Image saved as ./daire_yeni/Torus_1718799338.png
# Image saved as ./daire_yeni/Torus_1718799338.png
# Image saved as ./daire_yeni/Torus_1718799338.png
# Image saved as ./daire_yeni/Torus_1718799338.png
# Image saved as ./daire_yeni/Torus_1718799339.png
# Image saved as ./daire_yeni/Torus_1718799339.png
# Image saved as ./daire_yeni/Torus_1718799339.png
# Image saved as ./daire_yeni/Torus_1718799339.png
# Image saved as ./daire_yeni/Torus_1718799339.png
# Image saved as ./daire_yeni/Torus_1718799339.png
# Image saved as ./daire_yeni/Torus_1718799339.png
# Image saved as ./daire_yeni/Torus_1718799340.png
# Image saved as ./daire_yeni/Torus_1718799340.png
# Image saved as ./daire_yeni/Torus_1718799340.png
# Image saved as ./daire_yeni/Torus_1718799340.png
# Image saved as ./daire_yeni/Torus_1718799340.png
# Image saved as ./daire_yeni/Torus_1718799340.png
# Image saved as ./daire_yeni/Torus_1718799340.png
# Image saved as ./daire_yeni/Torus_1718799340.png
# Image saved as ./daire_yeni/Torus_1718799341.png
# Image saved as ./daire_yeni/Torus_1718799341.png
# Image saved as ./daire_yeni/Torus_1718799341.png
# Image saved as ./daire_yeni/Torus_1718799341.png
# Image saved as ./daire_yeni/Torus_1718799341.png
# Image saved as ./daire_yeni/Torus_1718799341.png
# Image saved as ./daire_yeni/Torus_1718799341.png
# Image saved as ./daire_yeni/Torus_1718799342.png
# Image saved as ./daire_yeni/Torus_1718799342.png
# Image saved as ./daire_yeni/Torus_1718799342.png
# Image saved as ./daire_yeni/Torus_1718799342.png
# Image saved as ./daire_yeni/Torus_1718799343.png
# Image saved as ./daire_yeni/Torus_1718799343.png
# Image saved as ./daire_yeni/Torus_1718799343.png
# Image saved as ./daire_yeni/Torus_1718799343.png
# Image saved as ./daire_yeni/Torus_1718799343.png
# Image saved as ./daire_yeni/Torus_1718799343.png
# Image saved as ./daire_yeni/Torus_1718799343.png
# Image saved as ./daire_yeni/Torus_1718799344.png
# Image saved as ./daire_yeni/Torus_1718799344.png
# Image saved as ./daire_yeni/Torus_1718799344.png
# Image saved as ./daire_yeni/Torus_1718799344.png
# Image saved as ./daire_yeni/Torus_1718799344.png
# Image saved as ./daire_yeni/Torus_1718799344.png
# Image saved as ./daire_yeni/Torus_1718799344.png
# Image saved as ./daire_yeni/Torus_1718799345.png
# Image saved as ./daire_yeni/Torus_1718799345.png
# Image saved as ./daire_yeni/Torus_1718799345.png
# Image saved as ./daire_yeni/Torus_1718799345.png
# Image saved as ./daire_yeni/Torus_1718799346.png
# Image saved as ./daire_yeni/Torus_1718799347.png
# Image saved as ./daire_yeni/Torus_1718799348.png
# Image saved as ./daire_yeni/Torus_1718799349.png
# Image saved as ./daire_yeni/Torus_1718799350.png
# Image saved as ./daire_yeni/Torus_1718799351.png
# Image saved as ./daire_yeni/Torus_1718799352.png
# Image saved as ./daire_yeni/Torus_1718799353.png
# Image saved as ./daire_yeni/Torus_1718799354.png
# Image saved as ./daire_yeni/Torus_1718799355.png
# Image saved as ./daire_yeni/Torus_1718799356.png
# Image saved as ./daire_yeni/Torus_1718799357.png
# Image saved as ./daire_yeni/Torus_1718799358.png
# Image saved as ./daire_yeni/Torus_1718799359.png
# Image saved as ./daire_yeni/Torus_1718799359.png
# Image saved as ./daire_yeni/Torus_1718799359.png
# Image saved as ./daire_yeni/Torus_1718799359.png
# Image saved as ./daire_yeni/Torus_1718799359.png
# Image saved as ./daire_yeni/Torus_1718799359.png
# Image saved as ./daire_yeni/Torus_1718799359.png
# Image saved as ./daire_yeni/Torus_1718799360.png
# Image saved as ./daire_yeni/Torus_1718799361.png
# Image saved as ./daire_yeni/Torus_1718799361.png
# Image saved as ./daire_yeni/Torus_1718799361.png
# Image saved as ./daire_yeni/Torus_1718799361.png
# Image saved as ./daire_yeni/Torus_1718799361.png
# Image saved as ./daire_yeni/Torus_1718799361.png
# Image saved as ./daire_yeni/Torus_1718799362.png
# Image saved as ./daire_yeni/Torus_1718799362.png
# Image saved as ./daire_yeni/Torus_1718799362.png
# Image saved as ./daire_yeni/Torus_1718799362.png
# Image saved as ./daire_yeni/Torus_1718799362.png
# Image saved as ./daire_yeni/Torus_1718799362.png
# Image saved as ./daire_yeni/Torus_1718799362.png
# Image saved as ./daire_yeni/Torus_1718799363.png
# Image saved as ./daire_yeni/Torus_1718799364.png
# Image saved as ./daire_yeni/Torus_1718799364.png
# Image saved as ./daire_yeni/Torus_1718799364.png
# Image saved as ./daire_yeni/Torus_1718799364.png
# Image saved as ./daire_yeni/Torus_1718799364.png
# Image saved as ./daire_yeni/Torus_1718799365.png
# Image saved as ./daire_yeni/Torus_1718799365.png
# Image saved as ./daire_yeni/Torus_1718799365.png
# Image saved as ./daire_yeni/Torus_1718799365.png
# Image saved as ./daire_yeni/Torus_1718799365.png
# Image saved as ./daire_yeni/Torus_1718799365.png
# Image saved as ./daire_yeni/Torus_1718799365.png
# Image saved as ./daire_yeni/Torus_1718799366.png
# Image saved as ./daire_yeni/Torus_1718799366.png
# Image saved as ./daire_yeni/Torus_1718799366.png
# Image saved as ./daire_yeni/Torus_1718799366.png
# Image saved as ./daire_yeni/Torus_1718799366.png
# Image saved as ./daire_yeni/Torus_1718799366.png
# Image saved as ./daire_yeni/Torus_1718799367.png
# Image saved as ./daire_yeni/Torus_1718799368.png
# Image saved as ./daire_yeni/Torus_1718799368.png
# Image saved as ./daire_yeni/Torus_1718799368.png
# Image saved as ./daire_yeni/Torus_1718799368.png
# Image saved as ./daire_yeni/Torus_1718799368.png
# Image saved as ./daire_yeni/Torus_1718799369.png
# Image saved as ./daire_yeni/Torus_1718799370.png
# Image saved as ./daire_yeni/Torus_1718799371.png
# Image saved as ./daire_yeni/Torus_1718799372.png
# Image saved as ./daire_yeni/Torus_1718799373.png
# Image saved as ./daire_yeni/Torus_1718799374.png
# Image saved as ./daire_yeni/Torus_1718799375.png
# Image saved as ./daire_yeni/Torus_1718799376.png
# Image saved as ./daire_yeni/Torus_1718799377.png
# Image saved as ./daire_yeni/Torus_1718799378.png
# Image saved as ./daire_yeni/Torus_1718799379.png
# Image saved as ./daire_yeni/Torus_1718799380.png
# Image saved as ./daire_yeni/Torus_1718799381.png
# Image saved as ./daire_yeni/Torus_1718799382.png
# Image saved as ./daire_yeni/Torus_1718799382.png
# Image saved as ./daire_yeni/Torus_1718799383.png
# Image saved as ./daire_yeni/Torus_1718799383.png
# Image saved as ./daire_yeni/Torus_1718799383.png
# Image saved as ./daire_yeni/Torus_1718799383.png
# Image saved as ./daire_yeni/Torus_1718799383.png
# Image saved as ./daire_yeni/Torus_1718799383.png
# Image saved as ./daire_yeni/Torus_1718799383.png
# Image saved as ./daire_yeni/Torus_1718799384.png
# Image saved as ./daire_yeni/Torus_1718799384.png
# Image saved as ./daire_yeni/Torus_1718799384.png
# Image saved as ./daire_yeni/Torus_1718799384.png
# Image saved as ./daire_yeni/Torus_1718799384.png
# Image saved as ./daire_yeni/Torus_1718799384.png
# Image saved as ./daire_yeni/Torus_1718799384.png
# Image saved as ./daire_yeni/Torus_1718799385.png
# Image saved as ./daire_yeni/Torus_1718799385.png
# Image saved as ./daire_yeni/Torus_1718799385.png
# Image saved as ./daire_yeni/Torus_1718799385.png
# Image saved as ./daire_yeni/Torus_1718799385.png
# Image saved as ./daire_yeni/Torus_1718799385.png
# Image saved as ./daire_yeni/Torus_1718799385.png
# Image saved as ./daire_yeni/Torus_1718799385.png
# Image saved as ./daire_yeni/Torus_1718799386.png
# Image saved as ./daire_yeni/Torus_1718799386.png
# Image saved as ./daire_yeni/Torus_1718799386.png
# Image saved as ./daire_yeni/Torus_1718799386.png
# Image saved as ./daire_yeni/Torus_1718799387.png
# Image saved as ./daire_yeni/Torus_1718799387.png
# Image saved as ./daire_yeni/Torus_1718799388.png
# Image saved as ./daire_yeni/Torus_1718799388.png
# Image saved as ./daire_yeni/Torus_1718799388.png
# Image saved as ./daire_yeni/Torus_1718799388.png
# Image saved as ./daire_yeni/Torus_1718799388.png
# Image saved as ./daire_yeni/Torus_1718799388.png
# Image saved as ./daire_yeni/Torus_1718799388.png
# Image saved as ./daire_yeni/Torus_1718799389.png
# Image saved as ./daire_yeni/Torus_1718799389.png
# Image saved as ./daire_yeni/Torus_1718799389.png
# Image saved as ./daire_yeni/Torus_1718799389.png
# Image saved as ./daire_yeni/Torus_1718799389.png
# Image saved as ./daire_yeni/Torus_1718799389.png
# Image saved as ./daire_yeni/Torus_1718799389.png
# Image saved as ./daire_yeni/Torus_1718799390.png
# Image saved as ./daire_yeni/Torus_1718799390.png
# Image saved as ./daire_yeni/Torus_1718799390.png
# Image saved as ./daire_yeni/Torus_1718799390.png
# Image saved as ./daire_yeni/Torus_1718799390.png
# Image saved as ./daire_yeni/Torus_1718799391.png
# Image saved as ./daire_yeni/Torus_1718799391.png
# Image saved as ./daire_yeni/Torus_1718799391.png
# ...
# Image saved as ./daire_yeni/Torus_1718799598.png
# Image saved as ./daire_yeni/Torus_1718799599.png
# Image saved as ./daire_yeni/Torus_1718799599.png
# Image saved as ./daire_yeni/Torus_1718799599.png
# Image saved as ./daire_yeni/Torus_1718799599.png
# Image saved as ./daire_yeni/Torus_1718799599.png
# Image saved as ./daire_yeni/Torus_1718799599.png
# Image saved as ./daire_yeni/Torus_1718799599.png
# Image saved as ./daire_yeni/Torus_1718799600.png
# Image saved as ./daire_yeni/Torus_1718799600.png
# Image saved as ./daire_yeni/Torus_1718799600.png
# Image saved as ./daire_yeni/Torus_1718799601.png
# Image saved as ./daire_yeni/Torus_1718799601.png
# Image saved as ./daire_yeni/Torus_1718799601.png
# Image saved as ./daire_yeni/Torus_1718799602.png
# Image saved as ./daire_yeni/Torus_1718799602.png
# Image saved as ./daire_yeni/Torus_1718799602.png
# Image saved as ./daire_yeni/Torus_1718799602.png
# Image saved as ./daire_yeni/Torus_1718799602.png
# Image saved as ./daire_yeni/Torus_1718799602.png
# Image saved as ./daire_yeni/Torus_1718799602.png
# Image saved as ./daire_yeni/Torus_1718799603.png
# Image saved as ./daire_yeni/Torus_1718799603.png
# Image saved as ./daire_yeni/Torus_1718799604.png
# Image saved as ./daire_yeni/Torus_1718799605.png
# Image saved as ./daire_yeni/Torus_1718799606.png
# Image saved as ./daire_yeni/Torus_1718799607.png
# Image saved as ./daire_yeni/Torus_1718799608.png
# Image saved as ./daire_yeni/Torus_1718799609.png
# Image saved as ./daire_yeni/Torus_1718799609.png
# Image saved as ./daire_yeni/Torus_1718799609.png
# Image saved as ./daire_yeni/Torus_1718799610.png
# Image saved as ./daire_yeni/Torus_1718799610.png
# Image saved as ./daire_yeni/Torus_1718799610.png
# Image saved as ./daire_yeni/Torus_1718799610.png
# Image saved as ./daire_yeni/Torus_1718799610.png
# Image saved as ./daire_yeni/Torus_1718799611.png
# Image saved as ./daire_yeni/Torus_1718799611.png
# Image saved as ./daire_yeni/Torus_1718799611.png
# Image saved as ./daire_yeni/Torus_1718799611.png
# Image saved as ./daire_yeni/Torus_1718799611.png
# Image saved as ./daire_yeni/Torus_1718799611.png
# Image saved as ./daire_yeni/Torus_1718799611.png
# Image saved as ./daire_yeni/Torus_1718799612.png
# Image saved as ./daire_yeni/Torus_1718799612.png
# Image saved as ./daire_yeni/Torus_1718799612.png
# Image saved as ./daire_yeni/Torus_1718799612.png
# Image saved as ./daire_yeni/Torus_1718799612.png
# Image saved as ./daire_yeni/Torus_1718799612.png
# Image saved as ./daire_yeni/Torus_1718799612.png
# Image saved as ./daire_yeni/Torus_1718799613.png
# Image saved as ./daire_yeni/Torus_1718799613.png
# Image saved as ./daire_yeni/Torus_1718799613.png
# Image saved as ./daire_yeni/Torus_1718799613.png
# Image saved as ./daire_yeni/Torus_1718799613.png
# Image saved as ./daire_yeni/Torus_1718799613.png
# Image saved as ./daire_yeni/Torus_1718799613.png
# Image saved as ./daire_yeni/Torus_1718799614.png
# Image saved as ./daire_yeni/Torus_1718799614.png
# Image saved as ./daire_yeni/Torus_1718799614.png
# Image saved as ./daire_yeni/Torus_1718799614.png
# Image saved as ./daire_yeni/Torus_1718799614.png
# Image saved as ./daire_yeni/Torus_1718799614.png
# Image saved as ./daire_yeni/Torus_1718799615.png
# Image saved as ./daire_yeni/Torus_1718799615.png
# Image saved as ./daire_yeni/Torus_1718799615.png
# Image saved as ./daire_yeni/Torus_1718799615.png
# Image saved as ./daire_yeni/Torus_1718799616.png
# Image saved as ./daire_yeni/Torus_1718799616.png
# Image saved as ./daire_yeni/Torus_1718799616.png
# Image saved as ./daire_yeni/Torus_1718799616.png
# Image saved as ./daire_yeni/Torus_1718799616.png
# Image saved as ./daire_yeni/Torus_1718799616.png
# Image saved as ./daire_yeni/Torus_1718799616.png
# Image saved as ./daire_yeni/Torus_1718799617.png
# Image saved as ./daire_yeni/Torus_1718799617.png
# Image saved as ./daire_yeni/Torus_1718799617.png
# Image saved as ./daire_yeni/Torus_1718799617.png
# Image saved as ./daire_yeni/Torus_1718799618.png
# Image saved as ./daire_yeni/Torus_1718799619.png
# Image saved as ./daire_yeni/Torus_1718799620.png
# Image saved as ./daire_yeni/Torus_1718799621.png
# Image saved as ./daire_yeni/Torus_1718799621.png
# Image saved as ./daire_yeni/Torus_1718799621.png
# Image saved as ./daire_yeni/Torus_1718799621.png
# Image saved as ./daire_yeni/Torus_1718799622.png
# Image saved as ./daire_yeni/Torus_1718799622.png
# Image saved as ./daire_yeni/Torus_1718799622.png
# Image saved as ./daire_yeni/Torus_1718799622.png
# Image saved as ./daire_yeni/Torus_1718799622.png
# Image saved as ./daire_yeni/Torus_1718799622.png
# Image saved as ./daire_yeni/Torus_1718799622.png
# Image saved as ./daire_yeni/Torus_1718799623.png
# Image saved as ./daire_yeni/Torus_1718799623.png
# Image saved as ./daire_yeni/Torus_1718799623.png
# Image saved as ./daire_yeni/Torus_1718799623.png
# Image saved as ./daire_yeni/Torus_1718799623.png
# Image saved as ./daire_yeni/Torus_1718799624.png
# Image saved as ./daire_yeni/Torus_1718799624.png
# Image saved as ./daire_yeni/Torus_1718799624.png
# Image saved as ./daire_yeni/Torus_1718799624.png
# Image saved as ./daire_yeni/Torus_1718799624.png
# Image saved as ./daire_yeni/Torus_1718799624.png
# Image saved as ./daire_yeni/Torus_1718799624.png
# Image saved as ./daire_yeni/Torus_1718799625.png
# Image saved as ./daire_yeni/Torus_1718799625.png
# Image saved as ./daire_yeni/Torus_1718799625.png
# Image saved as ./daire_yeni/Torus_1718799625.png
# Image saved as ./daire_yeni/Torus_1718799625.png
# Image saved as ./daire_yeni/Torus_1718799625.png
# Image saved as ./daire_yeni/Torus_1718799625.png
# Image saved as ./daire_yeni/Torus_1718799626.png
# Image saved as ./daire_yeni/Torus_1718799626.png
# Image saved as ./daire_yeni/Torus_1718799626.png
# Image saved as ./daire_yeni/Torus_1718799626.png
# Image saved as ./daire_yeni/Torus_1718799626.png
# Image saved as ./daire_yeni/Torus_1718799626.png
# Image saved as ./daire_yeni/Torus_1718799627.png
# Image saved as ./daire_yeni/Torus_1718799627.png
# Image saved as ./daire_yeni/Torus_1718799627.png
# Image saved as ./daire_yeni/Torus_1718799627.png
# Image saved as ./daire_yeni/Torus_1718799627.png
# Image saved as ./daire_yeni/Torus_1718799627.png
# Image saved as ./daire_yeni/Torus_1718799627.png
# Image saved as ./daire_yeni/Torus_1718799628.png
# Image saved as ./daire_yeni/Torus_1718799628.png
# Image saved as ./daire_yeni/Torus_1718799628.png
# Image saved as ./daire_yeni/Torus_1718799628.png
# Image saved as ./daire_yeni/Torus_1718799628.png
# Image saved as ./daire_yeni/Torus_1718799629.png
# Image saved as ./daire_yeni/Torus_1718799629.png
# Image saved as ./daire_yeni/Torus_1718799629.png
# Image saved as ./daire_yeni/Torus_1718799629.png
# Image saved as ./daire_yeni/Torus_1718799629.png
# Image saved as ./daire_yeni/Torus_1718799629.png
# Image saved as ./daire_yeni/Torus_1718799629.png
# Image saved as ./daire_yeni/Torus_1718799630.png
# Image saved as ./daire_yeni/Torus_1718799630.png
# Image saved as ./daire_yeni/Torus_1718799630.png
# Image saved as ./daire_yeni/Torus_1718799630.png
# Image saved as ./daire_yeni/Torus_1718799630.png
# Image saved as ./daire_yeni/Torus_1718799630.png
# Image saved as ./daire_yeni/Torus_1718799631.png
# Image saved as ./daire_yeni/Torus_1718799631.png
# Image saved as ./daire_yeni/Torus_1718799631.png
# Image saved as ./daire_yeni/Torus_1718799631.png
# Image saved as ./daire_yeni/Torus_1718799631.png
# Image saved as ./daire_yeni/Torus_1718799631.png
# Image saved as ./daire_yeni/Torus_1718799632.png
# Image saved as ./daire_yeni/Torus_1718799633.png
# Image saved as ./daire_yeni/Torus_1718799634.png
# Image saved as ./daire_yeni/Torus_1718799635.png
# Image saved as ./daire_yeni/Torus_1718799636.png
# Image saved as ./daire_yeni/Torus_1718799637.png
# Image saved as ./daire_yeni/Torus_1718799638.png
# Image saved as ./daire_yeni/Torus_1718799639.png
# Image saved as ./daire_yeni/Torus_1718799640.png
# Image saved as ./daire_yeni/Torus_1718799641.png
# Image saved as ./daire_yeni/Torus_1718799642.png
# Image saved as ./daire_yeni/Torus_1718799643.png
# Image saved as ./daire_yeni/Torus_1718799644.png
# Image saved as ./daire_yeni/Torus_1718799645.png
# Image saved as ./daire_yeni/Torus_1718799646.png
# Image saved as ./daire_yeni/Torus_1718799647.png
# Image saved as ./daire_yeni/Torus_1718799648.png
# Image saved as ./daire_yeni/Torus_1718799649.png
# Image saved as ./daire_yeni/Torus_1718799649.png
# Image saved as ./daire_yeni/Torus_1718799649.png
# Image saved as ./daire_yeni/Torus_1718799649.png
# Image saved as ./daire_yeni/Torus_1718799649.png
# Image saved as ./daire_yeni/Torus_1718799649.png
# Image saved as ./daire_yeni/Torus_1718799650.png
# Image saved as ./daire_yeni/Torus_1718799650.png
# Image saved as ./daire_yeni/Torus_1718799650.png
# Image saved as ./daire_yeni/Torus_1718799650.png
# Image saved as ./daire_yeni/Torus_1718799651.png
# Image saved as ./daire_yeni/Torus_1718799651.png
# Image saved as ./daire_yeni/Torus_1718799651.png
# Image saved as ./daire_yeni/Torus_1718799651.png
# Image saved as ./daire_yeni/Torus_1718799651.png
# Image saved as ./daire_yeni/Torus_1718799651.png
# Image saved as ./daire_yeni/Torus_1718799651.png
# Image saved as ./daire_yeni/Torus_1718799651.png
# Image saved as ./daire_yeni/Torus_1718799652.png
# Image saved as ./daire_yeni/Torus_1718799652.png
# Image saved as ./daire_yeni/Torus_1718799652.png
# Image saved as ./daire_yeni/Torus_1718799652.png
# Image saved as ./daire_yeni/Torus_1718799652.png
# Image saved as ./daire_yeni/Torus_1718799652.png
# Image saved as ./daire_yeni/Torus_1718799652.png
# Image saved as ./daire_yeni/Torus_1718799653.png
# Image saved as ./daire_yeni/Torus_1718799653.png
# Image saved as ./daire_yeni/Torus_1718799653.png
# Image saved as ./daire_yeni/Torus_1718799653.png
# Image saved as ./daire_yeni/Torus_1718799653.png
# Image saved as ./daire_yeni/Torus_1718799653.png
# Image saved as ./daire_yeni/Torus_1718799653.png
# Image saved as ./daire_yeni/Torus_1718799654.png
# Image saved as ./daire_yeni/Torus_1718799654.png
# Image saved as ./daire_yeni/Torus_1718799654.png
# Image saved as ./daire_yeni/Torus_1718799654.png
# Image saved as ./daire_yeni/Torus_1718799654.png
# Image saved as ./daire_yeni/Torus_1718799654.png
# Image saved as ./daire_yeni/Torus_1718799654.png
# Image saved as ./daire_yeni/Torus_1718799655.png
# Image saved as ./daire_yeni/Torus_1718799655.png
# Image saved as ./daire_yeni/Torus_1718799655.png
# Image saved as ./daire_yeni/Torus_1718799655.png
# Image saved as ./daire_yeni/Torus_1718799655.png
# Image saved as ./daire_yeni/Torus_1718799655.png
# Image saved as ./daire_yeni/Torus_1718799655.png
# Image saved as ./daire_yeni/Torus_1718799656.png
# Image saved as ./daire_yeni/Torus_1718799656.png
# Image saved as ./daire_yeni/Torus_1718799657.png
# Image saved as ./daire_yeni/Torus_1718799658.png
# Image saved as ./daire_yeni/Torus_1718799659.png
# Image saved as ./daire_yeni/Torus_1718799659.png
# Image saved as ./daire_yeni/Torus_1718799659.png
# Image saved as ./daire_yeni/Torus_1718799659.png
# Image saved as ./daire_yeni/Torus_1718799659.png
# Image saved as ./daire_yeni/Torus_1718799659.png
# Image saved as ./daire_yeni/Torus_1718799660.png
# Image saved as ./daire_yeni/Torus_1718799660.png
# Image saved as ./daire_yeni/Torus_1718799660.png
# Image saved as ./daire_yeni/Torus_1718799660.png
# Image saved as ./daire_yeni/Torus_1718799660.png
# Image saved as ./daire_yeni/Torus_1718799660.png
# Image saved as ./daire_yeni/Torus_1718799660.png
# Image saved as ./daire_yeni/Torus_1718799661.png
# Image saved as ./daire_yeni/Torus_1718799661.png
# Image saved as ./daire_yeni/Torus_1718799661.png
# Image saved as ./daire_yeni/Torus_1718799661.png
# Image saved as ./daire_yeni/Torus_1718799661.png
# Image saved as ./daire_yeni/Torus_1718799661.png
# Image saved as ./daire_yeni/Torus_1718799661.png
# Image saved as ./daire_yeni/Torus_1718799661.png
# Image saved as ./daire_yeni/Torus_1718799662.png
# Image saved as ./daire_yeni/Torus_1718799662.png
# Image saved as ./daire_yeni/Torus_1718799662.png
# Image saved as ./daire_yeni/Torus_1718799662.png
# Image saved as ./daire_yeni/Torus_1718799662.png
# Image saved as ./daire_yeni/Torus_1718799662.png
# Image saved as ./daire_yeni/Torus_1718799662.png
# Image saved as ./daire_yeni/Torus_1718799663.png
# Image saved as ./daire_yeni/Torus_1718799663.png
# Image saved as ./daire_yeni/Torus_1718799663.png
# Image saved as ./daire_yeni/Torus_1718799663.png
# Image saved as ./daire_yeni/Torus_1718799663.png
# Image saved as ./daire_yeni/Torus_1718799663.png
# Image saved as ./daire_yeni/Torus_1718799663.png
# Image saved as ./daire_yeni/Torus_1718799664.png
# Image saved as ./daire_yeni/Torus_1718799664.png
# Image saved as ./daire_yeni/Torus_1718799664.png
# Image saved as ./daire_yeni/Torus_1718799664.png
# Image saved as ./daire_yeni/Torus_1718799665.png
# Image saved as ./daire_yeni/Torus_1718799666.png
# Image saved as ./daire_yeni/Torus_1718799667.png
# Image saved as ./daire_yeni/Torus_1718799668.png
# Image saved as ./daire_yeni/Torus_1718799669.png
# Image saved as ./daire_yeni/Torus_1718799670.png
# Image saved as ./daire_yeni/Torus_1718799670.png
# Image saved as ./daire_yeni/Torus_1718799671.png
# Image saved as ./daire_yeni/Torus_1718799671.png
# Image saved as ./daire_yeni/Torus_1718799671.png
# Image saved as ./daire_yeni/Torus_1718799671.png
# Image saved as ./daire_yeni/Torus_1718799671.png
# Image saved as ./daire_yeni/Torus_1718799671.png
# Image saved as ./daire_yeni/Torus_1718799672.png
# Image saved as ./daire_yeni/Torus_1718799672.png
# Image saved as ./daire_yeni/Torus_1718799672.png
# Image saved as ./daire_yeni/Torus_1718799672.png
# Image saved as ./daire_yeni/Torus_1718799672.png
# Image saved as ./daire_yeni/Torus_1718799673.png
# Image saved as ./daire_yeni/Torus_1718799673.png
# Image saved as ./daire_yeni/Torus_1718799673.png
# Image saved as ./daire_yeni/Torus_1718799673.png
# Image saved as ./daire_yeni/Torus_1718799673.png
# Image saved as ./daire_yeni/Torus_1718799673.png
# Image saved as ./daire_yeni/Torus_1718799673.png
# Image saved as ./daire_yeni/Torus_1718799674.png
# Image saved as ./daire_yeni/Torus_1718799675.png
# Image saved as ./daire_yeni/Torus_1718799676.png
# Image saved as ./daire_yeni/Torus_1718799677.png
# Image saved as ./daire_yeni/Torus_1718799677.png
# Image saved as ./daire_yeni/Torus_1718799677.png
# Image saved as ./daire_yeni/Torus_1718799677.png
# Image saved as ./daire_yeni/Torus_1718799677.png
# Image saved as ./daire_yeni/Torus_1718799677.png
# Image saved as ./daire_yeni/Torus_1718799677.png
# Image saved as ./daire_yeni/Torus_1718799678.png
# Image saved as ./daire_yeni/Torus_1718799678.png
# Image saved as ./daire_yeni/Torus_1718799678.png
# Image saved as ./daire_yeni/Torus_1718799678.png
# Image saved as ./daire_yeni/Torus_1718799678.png
# Image saved as ./daire_yeni/Torus_1718799678.png
# Image saved as ./daire_yeni/Torus_1718799679.png
# Image saved as ./daire_yeni/Torus_1718799679.png
# Image saved as ./daire_yeni/Torus_1718799679.png
# Image saved as ./daire_yeni/Torus_1718799679.png
# Image saved as ./daire_yeni/Torus_1718799679.png
# Image saved as ./daire_yeni/Torus_1718799679.png
# Image saved as ./daire_yeni/Torus_1718799679.png
# Image saved as ./daire_yeni/Torus_1718799680.png
# Image saved as ./daire_yeni/Torus_1718799680.png
# Image saved as ./daire_yeni/Torus_1718799680.png
# Image saved as ./daire_yeni/Torus_1718799680.png
# Image saved as ./daire_yeni/Torus_1718799680.png
# Image saved as ./daire_yeni/Torus_1718799680.png
# Image saved as ./daire_yeni/Torus_1718799680.png
# Image saved as ./daire_yeni/Torus_1718799681.png
# Image saved as ./daire_yeni/Torus_1718799681.png
# Image saved as ./daire_yeni/Torus_1718799681.png
# Image saved as ./daire_yeni/Torus_1718799681.png
# Image saved as ./daire_yeni/Torus_1718799681.png
# Image saved as ./daire_yeni/Torus_1718799681.png
# Image saved as ./daire_yeni/Torus_1718799682.png
# Image saved as ./daire_yeni/Torus_1718799682.png
# Image saved as ./daire_yeni/Torus_1718799682.png
# Image saved as ./daire_yeni/Torus_1718799682.png
# Image saved as ./daire_yeni/Torus_1718799682.png
# Image saved as ./daire_yeni/Torus_1718799682.png
# Image saved as ./daire_yeni/Torus_1718799683.png
# Image saved as ./daire_yeni/Torus_1718799683.png
# Image saved as ./daire_yeni/Torus_1718799683.png
# Image saved as ./daire_yeni/Torus_1718799683.png
# Image saved as ./daire_yeni/Torus_1718799683.png

# %%
# 2 XML DOSYASI OLUŞTURUR BEYAZ KISMI RASTGELE OLARAK RESME YERLEŞTIRIR
### İŞLENMESİNİN İSTENEN VERİ SİYAH ZEMİN ÜZERİNE BEYAZ İSE BEYAZ OLAN CİSMİN TAMAMINI BİR KARE İÇERİSİNE ALARAK KARENİN KÖŞLERİNİ İŞARETLER 
### BU SAYEDE GÖRSELİN ETİKETLENMEK İSTENEN KISMI SEÇİLMİŞ OLUR 
### AMAÇ BASİT ETİKETLEME İŞLEMLERİ İÇİN İŞ YÜKÜNÜ AZALTMAK BİNLERCE VERİYİ TEK SEFERDE ETİKETLENMESİNİ SAĞLAMAK

import cv2
import numpy as np
import os
import random
import xml.etree.ElementTree as ET
from xml.dom import minidom

def detect_white_regions(image):
    # Beyaz renk için bir eşik değeri belirleyin
    lower_white = np.array([200, 200, 200], dtype=np.uint8)
    upper_white = np.array([255, 255, 255], dtype=np.uint8)

    # Belirlenen eşiklere göre maske oluşturun
    mask = cv2.inRange(image, lower_white, upper_white)

    # Maskeyi kullanarak beyaz bölgeleri tespit edin
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    return contours, mask

def resize_image(image, scale_factor):
    # Resmi rastgele bir ölçüde yeniden boyutlandırın
    height, width = image.shape[:2]
    new_height = int(height * scale_factor)
    new_width = int(width * scale_factor)
    resized_image = cv2.resize(image, (new_width, new_height))
    return resized_image

def create_xml_annotation(image_filename, objects, image_size):
    # XML dosyası için kök element oluşturun
    annotation = ET.Element("annotation")

    # Gerekli alt elementleri oluşturun
    folder = ET.SubElement(annotation, "folder")
    filename = ET.SubElement(annotation, "filename")
    path = ET.SubElement(annotation, "path")
    source = ET.SubElement(annotation, "source")
    database = ET.SubElement(source, "database")
    size = ET.SubElement(annotation, "size")
    width = ET.SubElement(size, "width")
    height = ET.SubElement(size, "height")
    depth = ET.SubElement(size, "depth")
    segmented = ET.SubElement(annotation, "segmented")

    # Alt elementlere değerleri atayın
    folder.text = ""
    filename.text = image_filename  # Resim dosya adı
    path.text = image_filename  # Resim dosya yolu
    database.text = "teknofest_atilay_tr"  # Veritabanı adı
    width.text = str(image_size[1])  # Görüntü genişliği
    height.text = str(image_size[0])  # Görüntü yüksekliği
    depth.text = str(image_size[2])  # Görüntü derinliği (kanal sayısı)
    segmented.text = "0"  # Segmentasyon yapılmamış

    # Her nesne için "object" elementleri oluşturun
    for obj in objects:
        object_elem = ET.SubElement(annotation, "object")
        name = ET.SubElement(object_elem, "name")
        pose = ET.SubElement(object_elem, "pose")
        truncated = ET.SubElement(object_elem, "truncated")
        difficult = ET.SubElement(object_elem, "difficult")
        occluded = ET.SubElement(object_elem, "occluded")
        bndbox = ET.SubElement(object_elem, "bndbox")
        xmin = ET.SubElement(bndbox, "xmin")
        xmax = ET.SubElement(bndbox, "xmax")
        ymin = ET.SubElement(bndbox, "ymin")
        ymax = ET.SubElement(bndbox, "ymax")

        # Her bir özellik için değerleri atayın
        name.text = "daire"  # Örneğin nesnenizin adı "daire" olarak varsayılmıştır
        pose.text = "Unspecified"
        truncated.text = "0"
        difficult.text = "0"
        occluded.text = "0"
        xmin.text = str(int(obj["cx"] - obj["w"] / 2))
        xmax.text = str(int(obj["cx"] + obj["w"] / 2))
        ymin.text = str(int(obj["cy"] - obj["h"] / 2))
        ymax.text = str(int(obj["cy"] + obj["h"] / 2))

    # XML dosyasını oluşturun ve kaydedin
    xml_filename = os.path.splitext(image_filename)[0] + ".xml"
    xml_path = os.path.join("./2_annotations", xml_filename)  # XML dosyasının kaydedileceği yol

    # XML verilerini minidom kullanarak bir string'e dönüştürün
    xml_string = minidom.parseString(ET.tostring(annotation, encoding='unicode')).toprettyxml(indent="  ")

    # Biçimlendirilmiş XML verilerini dosyaya yazın
    with open(xml_path, "w", encoding="utf-8") as f:
        f.write(xml_string)

def augment_images(input_folder, output_folder, num_images=1000, output_size=(800, 800), padding=15):
    try:
        os.makedirs(output_folder, exist_ok=True)
        os.makedirs("./2_annotations", exist_ok=True)  # XML dosyalarını kaydetmek için klasör oluştur

        # Giriş klasöründeki tüm dosyaları listele
        files = os.listdir(input_folder)
        image_files = [f for f in files if f.endswith('.jpg') or f.endswith('.png')]

        # İstenilen sayıda yeni görüntü oluştur
        for i in range(num_images):
            # Rastgele bir görüntü seç
            random_image_name = random.choice(image_files)
            image_path = os.path.join(input_folder, random_image_name)

            # Görüntüyü oku
            image = cv2.imread(image_path)
            if image is None:
                print(f"Görüntü okunamadı: {image_path}")
                continue

            # Beyaz bölgeleri bulma işlemi
            contours, mask = detect_white_regions(image)

            # Augmented görüntüyü oluştur
            augmented_image = np.zeros((output_size[0], output_size[1], 3), dtype=np.uint8)

            objects = []

            # Orijinal görüntü boyutlarını al
            height, width = image.shape[:2]

            for contour in contours:
                # Konturu çevreleyen dikdörtgeni bulun ve tampon alan ekleyin
                x, y, w, h = cv2.boundingRect(contour)

                # Kare boyutunu belirleyin
                size = max(w, h)
                x = max(0, x - padding)
                y = max(0, y - padding)
                size = min(min(width - x, height - y), size + 2 * padding)

                # Kare içine beyaz bölgeyi yerleştirin
                square_region = image[y:y+size, x:x+size].copy()

                # Rastgele bir ölçekte boyutlandırma faktörü seçin (0.5 ile 2 arasında)
                scale_factor = random.uniform(0.5, 2.0)
                resized_square_region = resize_image(square_region, scale_factor)

                # Kare içinde beyaz bölgeyi rastgele bir açıyla döndürün
                angle = np.random.randint(0, 360)
                rotation_matrix = cv2.getRotationMatrix2D((resized_square_region.shape[1]//2, resized_square_region.shape[0]//2), angle, 1.0)
                rotated_square_region = cv2.warpAffine(resized_square_region, rotation_matrix, (resized_square_region.shape[1], resized_square_region.shape[0]))

                # Rotated bölgeyi rastgele bir konuma yerleştirin
                new_x = np.random.randint(0, output_size[1] - rotated_square_region.shape[1])
                new_y = np.random.randint(0, output_size[0] - rotated_square_region.shape[0])

                # Rotated bölgenin merkezini hesaplayın
                center_x = new_x + rotated_square_region.shape[1] // 2
                center_y = new_y + rotated_square_region.shape[0] // 2

                # Koordinatları kaydedin (dairelerin merkezi, genişlik ve yükseklik)
                objects.append({
                    "cx": center_x, 
                    "cy": center_y, 
                    "w": rotated_square_region.shape[1], 
                    "h": rotated_square_region.shape[0]
                })

                # Yapıştırılan bölgeyi augment edilmiş görüntüye yerleştirin
                augmented_image[new_y:new_y+rotated_square_region.shape[0], new_x:new_x+rotated_square_region.shape[1]] = rotated_square_region

                # Masked bölgeleri siyaha çevir
                image[y:y+size, x:x+size] = 0

            # Yeni dosya adı ve yolu oluşturun
            name, ext = os.path.splitext(random_image_name)
            new_image_name = f"{name}_donduruldu_{i+1}{ext}"
            new_image_path = os.path.join(output_folder, new_image_name)

            # Görüntüyü kaydedin
            if not cv2.imwrite(new_image_path, augmented_image):
                print(f"Görüntü kaydedilemedi: {new_image_path}")

            # XML dosyasını oluşturun
            create_xml_annotation(new_image_name, objects, augmented_image.shape)

            print(f"{i+1}/{num_images} images augmented.")

    except Exception as e:
        print(f"Hata: {e}")

# Kullanım örneği
if __name__ == "__main__":
    input_folder = "./1_daireOlustur/"  # Giriş klasörü
    output_folder = "./2_dondur_rastgele_yerlestir/"  # Çıkış klasörüx

# %%
import cv2
import numpy as np
import os
import xml.etree.ElementTree as ET
from xml.dom import minidom

def detect_white_regions(image):
    lower_white = np.array([200, 200, 200], dtype=np.uint8)
    upper_white = np.array([255, 255, 255], dtype=np.uint8)
    mask = cv2.inRange(image, lower_white, upper_white)
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    return contours, mask

def detect_black_regions(image):  # white_rect parametresini kaldırdık
    lower_black = np.array([0, 0, 0], dtype=np.uint8)
    upper_black = np.array([50, 50, 50], dtype=np.uint8)
    mask = cv2.inRange(image, lower_black, upper_black)
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    black_objects = []
    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)
        black_objects.append({
            "xmin": x,
            "xmax": x + w,
            "ymin": y,
            "ymax": y + h
        })
    return black_objects

def create_xml_annotation(image_filename, objects, image_size):
    annotation = ET.Element("annotation")
    folder = ET.SubElement(annotation, "folder")
    filename = ET.SubElement(annotation, "filename")
    path = ET.SubElement(annotation, "path")
    source = ET.SubElement(annotation, "source")
    database = ET.SubElement(source, "database")
    size = ET.SubElement(annotation, "size")
    width = ET.SubElement(size, "width")
    height = ET.SubElement(size, "height")
    depth = ET.SubElement(size, "depth")
    segmented = ET.SubElement(annotation, "segmented")
    folder.text = ""
    filename.text = image_filename
    path.text = image_filename
    database.text = "teknofest_atilay_tr"
    width.text = str(image_size[1])
    height.text = str(image_size[0])
    depth.text = str(image_size[2])
    segmented.text = "0"
    for obj in objects:
        object_elem = ET.SubElement(annotation, "object")
        name = ET.SubElement(object_elem, "name")
        pose = ET.SubElement(object_elem, "pose")
        truncated = ET.SubElement(object_elem, "truncated")
        difficult = ET.SubElement(object_elem, "difficult")
        occluded = ET.SubElement(object_elem, "occluded")
        bndbox = ET.SubElement(object_elem, "bndbox")
        xmin = ET.SubElement(bndbox, "xmin")
        xmax = ET.SubElement(bndbox, "xmax")
        ymin = ET.SubElement(bndbox, "ymin")
        ymax = ET.SubElement(bndbox, "ymax")
        name.text = obj["name"]
        pose.text = "Unspecified"
        truncated.text = "0"
        difficult.text = "0"
        occluded.text = "0"
        xmin.text = str(obj["xmin"])
        xmax.text = str(obj["xmax"])
        ymin.text = str(obj["ymin"])
        ymax.text = str(obj["ymax"])
    xml_filename = os.path.splitext(image_filename)[0] + ".xml"
    xml_path = os.path.join("./3_annotations", xml_filename)
    xml_string = minidom.parseString(ET.tostring(annotation, encoding='unicode')).toprettyxml(indent="  ")
    with open(xml_path, "w", encoding="utf-8") as f:
        f.write(xml_string)

def process_images(input_folder, output_folder):
    try:
        os.makedirs(output_folder, exist_ok=True)
        os.makedirs("./3_annotations", exist_ok=True)
        files = os.listdir(input_folder)
        image_files = [f for f in files if f.endswith('.jpg') or f.endswith('.png')]
        for image_name in image_files:
            image_path = os.path.join(input_folder, image_name)
            print(f"Processing {image_path}")
            image = cv2.imread(image_path)
            if image is None:
                print(f"Görüntü okunamadı: {image_path}")
                continue
            white_contours, _ = detect_white_regions(image)
            objects = []
            for contour in white_contours:
                # Dış çemberin sınırlarını al
                x, y, w, h = cv2.boundingRect(contour)
                white_rect = {
                    "xmin": x,
                    "xmax": x + w,
                    "ymin": y,
                    "ymax": y + h
                }
                objects.append({
                    "name": "white_region",
                    "xmin": x,
                    "xmax": x + w,
                    "ymin": y,
                    "ymax": y + h
                })
                # İç sınırları bulmak için konturu kullan:
                for i in range(white_rect["xmin"] + 1, white_rect["xmax"]):
                    for j in range(white_rect["ymin"] + 1, white_rect["ymax"]):
                        # Belirtilen noktanın konturun içinde olup olmadığını kontrol et
                        inside = cv2.pointPolygonTest(contour, (i, j), False)
                        if inside >= 0:  # İçerde ise:
                            # İçi işaretle:
                            cv2.circle(image, (i, j), 1, (0, 0, 255), -1)
                            # Bu iç noktaya ait dikdörtgen bilgisi:
                            inner_rect = {
                                "xmin": i,
                                "xmax": i,
                                "ymin": j,
                                "ymax": j
                            }
                            objects.append({
                                "name": "inner_white_region",
                                "xmin": inner_rect["xmin"],
                                "xmax": inner_rect["xmax"],
                                "ymin": inner_rect["ymin"],
                                "ymax": inner_rect["ymax"]
                            })
                            break  # Aynı satırdaki diğer noktaları kontrol etmekten vazgeç
            # Tüm siyah bölgeleri tespit et
            black_objects = detect_black_regions(image)  
            for black_obj in black_objects:
                # İç çemberin sınırlarını beyaz alanın içinde tut
                # Sadece koordinatları sınırlar içinde kalacak şekilde ayarlayın:
                black_obj["xmin"] = max(black_obj["xmin"], white_rect["xmin"])
                black_obj["xmax"] = min(black_obj["xmax"], white_rect["xmax"])
                black_obj["ymin"] = max(black_obj["ymin"], white_rect["ymin"])
                black_obj["ymax"] = min(black_obj["ymax"], white_rect["ymax"])
                objects.append({
                    "name": "black_region",
                    "xmin": black_obj["xmin"],
                    "xmax": black_obj["xmax"],
                    "ymin": black_obj["ymin"],
                    "ymax": black_obj["ymax"]
                })
            # Çizim işlemi:
            for obj in objects:
                if obj["name"] == "white_region":
                    cv2.rectangle(image, (obj["xmin"], obj["ymin"]), (obj["xmax"], obj["ymax"]), (0, 255, 0), 2)
                elif obj["name"] == "black_region":
                    cv2.rectangle(image, (obj["xmin"], obj["ymin"]), (obj["xmax"], obj["ymax"]), (0, 0, 255), 2)
                elif obj["name"] == "inner_white_region":
                    cv2.rectangle(image, (obj["xmin"], obj["ymin"]), (obj["xmax"], obj["ymax"]), (255, 0, 0), 2)
            # Daire kalınlığını hesapla
            if len(objects) >= 2:  # Hem beyaz hem de siyah alan tespit edildiyse
                # black_rect ve white_rect'i doğru yerlere ata
                white_rect = None
                black_rect = None
                for i, obj in enumerate(objects):
                    if obj["name"] == "white_region":
                        white_rect = obj
                    elif obj["name"] == "black_region":
                        black_rect = obj
                # Eğer her ikisi de bulunduysa:
                if white_rect and black_rect:
                    # Köşeler arasındaki mesafeleri hesapla
                    top_distance = abs(white_rect["ymin"] - black_rect["ymin"])
                    bottom_distance = abs(white_rect["ymax"] - black_rect["ymax"])
                    left_distance = abs(white_rect["xmin"] - black_rect["xmin"])
                    right_distance = abs(white_rect["xmax"] - black_rect["xmax"])
                    # Ortalama daire kalınlığını hesapla
                    circle_thickness = (top_distance + bottom_distance + left_distance + right_distance) / 4
                    print(f"Daire kalınlığı: {circle_thickness} piksel")
            new_image_name = f"{image_name}"  # Yeni dosya adı oluştur
            new_image_path = os.path.join(output_folder, new_image_name)  # Yeni dosya yolunu oluştur
            print(f"Saving {new_image_path}")
            if not cv2.imwrite(new_image_path, image):
                print(f"Görüntü kaydedilemedi: {new_image_path}")
                continue
            create_xml_annotation(new_image_name, objects, image.shape)
            print(f"{image_name} processed.")
    except Exception as e:
        print(f"Hata: {e}")

if __name__ == "__main__":
    # xml dosyaları 3_annotations dosyasına kaydedilir
    input_folder = "./daire_yeni/"
    output_folder = "./3_işaretli_resimler"
    process_images(input_folder, output_folder)
# Out:
# Processing ./daire_yeni/Torus_1718799431.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799431.png
# Torus_1718799431.png processed.
# Processing ./daire_yeni/Torus_1718799558.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799558.png
# Torus_1718799558.png processed.
# Processing ./daire_yeni/Torus_1718799483.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799483.png
# Torus_1718799483.png processed.
# Processing ./daire_yeni/Torus_1718799179.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799179.png
# Torus_1718799179.png processed.
# Processing ./daire_yeni/Torus_1718799356.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799356.png
# Torus_1718799356.png processed.
# Processing ./daire_yeni/Torus_1718799480.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799480.png
# Torus_1718799480.png processed.
# Processing ./daire_yeni/Torus_1718799122.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799122.png
# Torus_1718799122.png processed.
# Processing ./daire_yeni/Torus_1718799228.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799228.png
# Torus_1718799228.png processed.
# Processing ./daire_yeni/Torus_1718799140.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799140.png
# Torus_1718799140.png processed.
# Processing ./daire_yeni/Torus_1718799597.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799597.png
# Torus_1718799597.png processed.
# Processing ./daire_yeni/Torus_1718799408.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799408.png
# Torus_1718799408.png processed.
# Processing ./daire_yeni/Torus_1718799352.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799352.png
# Torus_1718799352.png processed.
# Processing ./daire_yeni/Torus_1718799149.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799149.png
# Torus_1718799149.png processed.
# Processing ./daire_yeni/Torus_1718799368.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799368.png
# Torus_1718799368.png processed.
# Processing ./daire_yeni/Torus_1718799182.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799182.png
# Torus_1718799182.png processed.
# Processing ./daire_yeni/Torus_1718799645.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799645.png
# Torus_1718799645.png processed.
# Processing ./daire_yeni/Torus_1718799173.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799173.png
# Torus_1718799173.png processed.
# Processing ./daire_yeni/Torus_1718799381.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799381.png
# Torus_1718799381.png processed.
# Processing ./daire_yeni/Torus_1718799444.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799444.png
# Torus_1718799444.png processed.
# Processing ./daire_yeni/Torus_1718799172.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799172.png
# Torus_1718799172.png processed.
# Processing ./daire_yeni/Torus_1718799292.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799292.png
# Torus_1718799292.png processed.
# Processing ./daire_yeni/Torus_1718799413.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799413.png
# Torus_1718799413.png processed.
# Processing ./daire_yeni/Torus_1718799327.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799327.png
# Torus_1718799327.png processed.
# Processing ./daire_yeni/Torus_1718799606.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799606.png
# Torus_1718799606.png processed.
# Processing ./daire_yeni/Torus_1718799266.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799266.png
# Torus_1718799266.png processed.
# Processing ./daire_yeni/Torus_1718799337.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799337.png
# Torus_1718799337.png processed.
# Processing ./daire_yeni/Torus_1718799509.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799509.png
# Torus_1718799509.png processed.
# Processing ./daire_yeni/Torus_1718799229.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799229.png
# Torus_1718799229.png processed.
# Processing ./daire_yeni/Torus_1718799278.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799278.png
# Torus_1718799278.png processed.
# Processing ./daire_yeni/Torus_1718799680.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799680.png
# Torus_1718799680.png processed.
# Processing ./daire_yeni/Torus_1718799311.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799311.png
# Torus_1718799311.png processed.
# Processing ./daire_yeni/Torus_1718799113.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799113.png
# Torus_1718799113.png processed.
# Processing ./daire_yeni/Torus_1718799156.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799156.png
# Torus_1718799156.png processed.
# Processing ./daire_yeni/Torus_1718799530.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799530.png
# Torus_1718799530.png processed.
# Processing ./daire_yeni/Torus_1718799416.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799416.png
# Torus_1718799416.png processed.
# Processing ./daire_yeni/Torus_1718799335.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799335.png
# Torus_1718799335.png processed.
# Processing ./daire_yeni/Torus_1718799295.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799295.png
# Torus_1718799295.png processed.
# Processing ./daire_yeni/Torus_1718799672.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799672.png
# Torus_1718799672.png processed.
# Processing ./daire_yeni/Torus_1718799164.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799164.png
# Torus_1718799164.png processed.
# Processing ./daire_yeni/Torus_1718799153.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799153.png
# Torus_1718799153.png processed.
# Processing ./daire_yeni/Torus_1718799425.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799425.png
# Torus_1718799425.png processed.
# Processing ./daire_yeni/Torus_1718799126.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799126.png
# Torus_1718799126.png processed.
# Processing ./daire_yeni/Torus_1718799418.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799418.png
# Torus_1718799418.png processed.
# Processing ./daire_yeni/Torus_1718799187.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799187.png
# Torus_1718799187.png processed.
# Processing ./daire_yeni/Torus_1718799602.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799602.png
# Torus_1718799602.png processed.
# Processing ./daire_yeni/Torus_1718799189.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799189.png
# Torus_1718799189.png processed.
# Processing ./daire_yeni/Torus_1718799663.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799663.png
# Torus_1718799663.png processed.
# Processing ./daire_yeni/Torus_1718799141.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799141.png
# Torus_1718799141.png processed.
# Processing ./daire_yeni/Torus_1718799165.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799165.png
# Torus_1718799165.png processed.
# Processing ./daire_yeni/Torus_1718799270.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799270.png
# Torus_1718799270.png processed.
# Processing ./daire_yeni/Torus_1718799411.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799411.png
# Torus_1718799411.png processed.
# Processing ./daire_yeni/Torus_1718799420.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799420.png
# Torus_1718799420.png processed.
# Processing ./daire_yeni/Torus_1718799427.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799427.png
# Torus_1718799427.png processed.
# Processing ./daire_yeni/Torus_1718799351.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799351.png
# Torus_1718799351.png processed.
# Processing ./daire_yeni/Torus_1718799473.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799473.png
# Torus_1718799473.png processed.
# Processing ./daire_yeni/Torus_1718799384.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799384.png
# Torus_1718799384.png processed.
# Processing ./daire_yeni/Torus_1718799533.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799533.png
# Torus_1718799533.png processed.
# Processing ./daire_yeni/Torus_1718799460.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799460.png
# Torus_1718799460.png processed.
# Processing ./daire_yeni/Torus_1718799490.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799490.png
# Torus_1718799490.png processed.
# Processing ./daire_yeni/Torus_1718799232.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799232.png
# Torus_1718799232.png processed.
# Processing ./daire_yeni/Torus_1718799296.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799296.png
# Torus_1718799296.png processed.
# Processing ./daire_yeni/Torus_1718799517.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799517.png
# Torus_1718799517.png processed.
# Processing ./daire_yeni/Torus_1718799184.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799184.png
# Torus_1718799184.png processed.
# Processing ./daire_yeni/Torus_1718799493.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799493.png
# Torus_1718799493.png processed.
# Processing ./daire_yeni/Torus_1718799601.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799601.png
# Torus_1718799601.png processed.
# Processing ./daire_yeni/Torus_1718799090.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799090.png
# Torus_1718799090.png processed.
# Processing ./daire_yeni/Torus_1718799196.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799196.png
# Torus_1718799196.png processed.
# Processing ./daire_yeni/Torus_1718799610.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799610.png
# Torus_1718799610.png processed.
# Processing ./daire_yeni/Torus_1718799357.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799357.png
# Torus_1718799357.png processed.
# Processing ./daire_yeni/Torus_1718799125.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799125.png
# Torus_1718799125.png processed.
# Processing ./daire_yeni/Torus_1718799452.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799452.png
# Torus_1718799452.png processed.
# Processing ./daire_yeni/Torus_1718799105.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799105.png
# Torus_1718799105.png processed.
# Processing ./daire_yeni/Torus_1718799099.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799099.png
# Torus_1718799099.png processed.
# Processing ./daire_yeni/Torus_1718799441.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799441.png
# Torus_1718799441.png processed.
# Processing ./daire_yeni/Torus_1718799405.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799405.png
# Torus_1718799405.png processed.
# Processing ./daire_yeni/Torus_1718799550.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799550.png
# Torus_1718799550.png processed.
# Processing ./daire_yeni/Torus_1718799190.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799190.png
# Torus_1718799190.png processed.
# Processing ./daire_yeni/Torus_1718799618.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799618.png
# Torus_1718799618.png processed.
# Processing ./daire_yeni/Torus_1718799650.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799650.png
# Torus_1718799650.png processed.
# Processing ./daire_yeni/Torus_1718799170.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799170.png
# Torus_1718799170.png processed.
# Processing ./daire_yeni/Torus_1718799372.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799372.png
# Torus_1718799372.png processed.
# Processing ./daire_yeni/Torus_1718799642.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799642.png
# Torus_1718799642.png processed.
# Processing ./daire_yeni/Torus_1718799183.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799183.png
# Torus_1718799183.png processed.
# Processing ./daire_yeni/Torus_1718799440.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799440.png
# Torus_1718799440.png processed.
# Processing ./daire_yeni/Torus_1718799202.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799202.png
# Torus_1718799202.png processed.
# Processing ./daire_yeni/Torus_1718799211.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799211.png
# Torus_1718799211.png processed.
# Processing ./daire_yeni/Torus_1718799497.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799497.png
# Torus_1718799497.png processed.
# Processing ./daire_yeni/Torus_1718799526.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799526.png
# Torus_1718799526.png processed.
# Processing ./daire_yeni/Torus_1718799521.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799521.png
# Torus_1718799521.png processed.
# Processing ./daire_yeni/Torus_1718799545.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799545.png
# Torus_1718799545.png processed.
# Processing ./daire_yeni/Torus_1718799474.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799474.png
# Torus_1718799474.png processed.
# Processing ./daire_yeni/Torus_1718799107.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799107.png
# Torus_1718799107.png processed.
# Processing ./daire_yeni/Torus_1718799546.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799546.png
# Torus_1718799546.png processed.
# Processing ./daire_yeni/Torus_1718799286.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799286.png
# Torus_1718799286.png processed.
# Processing ./daire_yeni/Torus_1718799414.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799414.png
# Torus_1718799414.png processed.
# Processing ./daire_yeni/Torus_1718799178.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799178.png
# Torus_1718799178.png processed.
# Processing ./daire_yeni/Torus_1718799661.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799661.png
# Torus_1718799661.png processed.
# Processing ./daire_yeni/Torus_1718799605.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799605.png
# Torus_1718799605.png processed.
# Processing ./daire_yeni/Torus_1718799514.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799514.png
# Torus_1718799514.png processed.
# Processing ./daire_yeni/Torus_1718799364.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799364.png
# Torus_1718799364.png processed.
# Processing ./daire_yeni/Torus_1718799233.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799233.png
# Torus_1718799233.png processed.
# Processing ./daire_yeni/Torus_1718799622.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799622.png
# Torus_1718799622.png processed.
# Processing ./daire_yeni/Torus_1718799426.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799426.png
# Torus_1718799426.png processed.
# Processing ./daire_yeni/Torus_1718799496.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799496.png
# Torus_1718799496.png processed.
# Processing ./daire_yeni/Torus_1718799243.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799243.png
# Torus_1718799243.png processed.
# Processing ./daire_yeni/Torus_1718799300.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799300.png
# Torus_1718799300.png processed.
# Processing ./daire_yeni/Torus_1718799670.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799670.png
# Torus_1718799670.png processed.
# Processing ./daire_yeni/Torus_1718799124.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799124.png
# Torus_1718799124.png processed.
# Processing ./daire_yeni/Torus_1718799177.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799177.png
# Torus_1718799177.png processed.
# Processing ./daire_yeni/Torus_1718799272.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799272.png
# Torus_1718799272.png processed.
# Processing ./daire_yeni/Torus_1718799147.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799147.png
# Torus_1718799147.png processed.
# Processing ./daire_yeni/Torus_1718799598.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799598.png
# Torus_1718799598.png processed.
# Processing ./daire_yeni/Torus_1718799578.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799578.png
# Torus_1718799578.png processed.
# Processing ./daire_yeni/Torus_1718799565.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799565.png
# Torus_1718799565.png processed.
# Processing ./daire_yeni/Torus_1718799343.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799343.png
# Torus_1718799343.png processed.
# Processing ./daire_yeni/Torus_1718799637.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799637.png
# Torus_1718799637.png processed.
# Processing ./daire_yeni/Torus_1718799181.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799181.png
# Torus_1718799181.png processed.
# Processing ./daire_yeni/Torus_1718799455.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799455.png
# Torus_1718799455.png processed.
# Processing ./daire_yeni/Torus_1718799595.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799595.png
# Torus_1718799595.png processed.
# Processing ./daire_yeni/Torus_1718799520.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799520.png
# Torus_1718799520.png processed.
# Processing ./daire_yeni/Torus_1718799151.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799151.png
# Torus_1718799151.png processed.
# Processing ./daire_yeni/Torus_1718799246.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799246.png
# Torus_1718799246.png processed.
# Processing ./daire_yeni/Torus_1718799085.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799085.png
# Torus_1718799085.png processed.
# Processing ./daire_yeni/Torus_1718799677.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799677.png
# Torus_1718799677.png processed.
# Processing ./daire_yeni/Torus_1718799310.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799310.png
# Torus_1718799310.png processed.
# Processing ./daire_yeni/Torus_1718799511.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799511.png
# Torus_1718799511.png processed.
# Processing ./daire_yeni/Torus_1718799220.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799220.png
# Torus_1718799220.png processed.
# Processing ./daire_yeni/Torus_1718799527.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799527.png
# Torus_1718799527.png processed.
# Processing ./daire_yeni/Torus_1718799358.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799358.png
# Torus_1718799358.png processed.
# Processing ./daire_yeni/Torus_1718799186.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799186.png
# Torus_1718799186.png processed.
# Processing ./daire_yeni/Torus_1718799347.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799347.png
# Torus_1718799347.png processed.
# Processing ./daire_yeni/Torus_1718799283.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799283.png
# Torus_1718799283.png processed.
# Processing ./daire_yeni/Torus_1718799459.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799459.png
# Torus_1718799459.png processed.
# Processing ./daire_yeni/Torus_1718799648.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799648.png
# Torus_1718799648.png processed.
# Processing ./daire_yeni/Torus_1718799476.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799476.png
# Torus_1718799476.png processed.
# Processing ./daire_yeni/Torus_1718799329.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799329.png
# Torus_1718799329.png processed.
# Processing ./daire_yeni/Torus_1718799501.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799501.png
# Torus_1718799501.png processed.
# Processing ./daire_yeni/Torus_1718799522.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799522.png
# Torus_1718799522.png processed.
# Processing ./daire_yeni/Torus_1718799100.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799100.png
# Torus_1718799100.png processed.
# Processing ./daire_yeni/Torus_1718799137.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799137.png
# Torus_1718799137.png processed.
# Processing ./daire_yeni/Torus_1718799207.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799207.png
# Torus_1718799207.png processed.
# Processing ./daire_yeni/Torus_1718799123.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799123.png
# Torus_1718799123.png processed.
# Processing ./daire_yeni/Torus_1718799599.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799599.png
# Torus_1718799599.png processed.
# Processing ./daire_yeni/Torus_1718799230.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799230.png
# Torus_1718799230.png processed.
# Processing ./daire_yeni/Torus_1718799276.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799276.png
# Torus_1718799276.png processed.
# Processing ./daire_yeni/Torus_1718799205.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799205.png
# Torus_1718799205.png processed.
# Processing ./daire_yeni/Torus_1718799252.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799252.png
# Torus_1718799252.png processed.
# Processing ./daire_yeni/Torus_1718799116.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799116.png
# Torus_1718799116.png processed.
# Processing ./daire_yeni/Torus_1718799643.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799643.png
# Torus_1718799643.png processed.
# Processing ./daire_yeni/Torus_1718799443.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799443.png
# Torus_1718799443.png processed.
# Processing ./daire_yeni/Torus_1718799397.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799397.png
# Torus_1718799397.png processed.
# Processing ./daire_yeni/Torus_1718799135.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799135.png
# Torus_1718799135.png processed.
# Processing ./daire_yeni/Torus_1718799375.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799375.png
# Torus_1718799375.png processed.
# Processing ./daire_yeni/Torus_1718799388.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799388.png
# Torus_1718799388.png processed.
# Processing ./daire_yeni/Torus_1718799651.png
# Daire kalınlığı: 0.0 piksel
# Saving ./3_işaretli_resimler/Torus_1718799651.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 190
#     188 input_folder = "./daire_yeni/"
#     189 output_folder = "./3_işaretli_resimler"
# --> 190 process_images(input_folder, output_folder)
#
# Cell In[29], line 181, in process_images(input_folder, output_folder)
#     179             print(f"Görüntü kaydedilemedi: {new_image_path}")
#     180             continue
# --> 181         create_xml_annotation(new_image_name, objects, image.shape)
#     182         print(f"{image_name} processed.")
#     183 except Exception as e:
#
# Cell In[29], line 73, in create_xml_annotation(image_filename, objects, image_size)
#      71 xml_filename = os.path.splitext(image_filename)[0] + ".xml"
#      72 xml_path = os.path.join("./3_annotations", xml_filename)
# ---> 73 xml_string = minidom.parseString(ET.tostring(annotation, encoding='unicode')).toprettyxml(indent="  ")
#      74 with open(xml_path, "w", encoding="utf-8") as f:
#      75     f.write(xml_string)
#
# File ~/miniconda3/envs/htpu/lib/python3.9/xml/dom/minidom.py:1998, in parseString(string, parser)
#    1996 if parser is None:
#    1997     from xml.dom import expatbuilder
# -> 1998     return expatbuilder.parseString(string)
#    1999 else:
#    2000     from xml.dom import pulldom
#
# File ~/miniconda3/envs/htpu/lib/python3.9/xml/dom/expatbuilder.py:925, in parseString(string, namespaces)
#     923 else:
#     924     builder = ExpatBuilder()
# --> 925 return builder.parseString(string)
#
# File ~/miniconda3/envs/htpu/lib/python3.9/xml/dom/expatbuilder.py:223, in ExpatBuilder.parseString(self, string)
#     221 parser = self.getParser()
#     222 try:
# --> 223     parser.Parse(string, True)
#     224     self._setup_subset(string)
#     225 except ParseEscape:
#
# File /croot/python-split_1715024103552/work/Modules/pyexpat.c:466, in EndElement()
#
# File ~/miniconda3/envs/htpu/lib/python3.9/xml/dom/expatbuilder.py:789, in Namespaces.end_element_handler(self, name)
#     781             a.ownerElement = node
#     783 if __debug__:
#     784     # This only adds some asserts to the original
#     785     # end_element_handler(), so we only define this when -O is not
#     786     # used.  If changing one, be sure to check the other to see if
#     787     # it needs to be changed as well.
#     788     #
# --> 789     def end_element_handler(self, name):
#     790         curNode = self.curNode
#     791         if ' ' in name:
#
# KeyboardInterrupt:
